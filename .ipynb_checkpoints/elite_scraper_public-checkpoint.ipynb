# %%
from dateutil.relativedelta import relativedelta
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import datetime
import argparse
import time
import re
import os

# %%
from dateutil.relativedelta import relativedelta
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import datetime
import argparse
import time
import re
import os

# # league names
leagues = ['CCHL2','NHL','NLA','USHL','BCHL', 'SJHL', 'AHL','SuperElit', 'WHL', 
           'CCHL','Jr. A SM-liiga','OHL','MHL','SHL','NCAA','Liiga', 'DEL', 'Slovakia',
           'Allsvenskan','QMJHL','AJHL','OJHL','KHL','VHL','Czech','Czech2']

# start and end years to scrape data
start_year = 2005
end_year = 2019

# create season labels and get current season
seasons = [f'{s}-{s + 1}' for s in range(start_year, end_year + 1)]

# base url for ep website
base_url = 'https://www.eliteprospects.com'

# output meta data
tables = {
    'team_standing' : {'csv' : 'team_stats.csv',
                       'postgres' : 'team_stats'},
    'skaters' : {'csv' : 'skater_stats.csv',
                 'postgres' : 'skater_stats'},
    'goalies' : {'csv' : 'goalie_stats.csv',
                 'postgres' : 'goalie_stats'},
    'player_info' : {'csv' : 'player_info.csv',
                     'postgres' : 'player_info'},
         }

def get_unique_players(player_stats, goalie_stats):
    '''This function takes skater and goalie stats and returns list of unique 
    dataframe of playerids and player shortnames.
    '''
    player_cols = ['playerid', 'shortname']
    
    players = pd.concat([player_stats[player_cols].drop_duplicates(player_cols),
                         goalie_stats[player_cols].drop_duplicates(player_cols)])
    
    return players

def get_draft_eligibility(df):
    '''Return the first year a player is NHL draft eligible'''

    df.set_index('playerid', inplace=True)

    # create a series filled with valueus of Birth year + 18 on September 15th 
    draft_days = pd.to_datetime(dict(year=df.date_of_birth.dt.year.values + 18,
                        month=np.full((len(df), ), 9),
                        day=np.full((len(df), ), 15))) 

    draft_days.index = df.index

    # check if player will be 18 years old by September 15th of draft year
    df['draft_year_eligible'] = np.where((draft_days - df['date_of_birth']) / np.timedelta64(1, 'Y') >= 18,
                                             df.date_of_birth.dt.year.values + 18,
                                             df.date_of_birth.dt.year.values + 19) 

    return df.reset_index()

def get_current_year(date):
    '''Return hockey season label based on what the current date is'''
    if date.month >= 1 and date.month <= 9:
        return f'{date.year - 1}-{date.year}'

    else:
        return f'{date.year}-{date.year + 1}'

# def load_db_credentials():
#     '''Load database credentials from bash_profile'''

#     user = os.environ['db_user']
#     password = os.environ['db_pass']
#     server = os.environ['db_host']
#     database = os.environ['db_name']
#     port = os.environ['db_port']

#     return user, password, server, database, port

# def output_to_db(df, name):
#     '''Writes a dataframe to database using the table metadata outlined at script instantiation'''

#     # get db credentials
#     user, password, server, database, port = load_db_credentials()
#     # create a connection to the database
#     engine = create_engine(f'postgresql://{user}:{password}@{server}:{port}/{database}')
#     # add a load date field
#     df = df.assign(load_date = datetime.date.today())
#     # write the values to the database
#     df.to_sql(tables[name]['postgres'], engine, if_exists='append', index = False )

def output_to_csv(df, name):
    '''Writes a dataframe to csv file using the table metadata outlined at script instantiation'''
    table = tables[name]['csv']
    # write the values to the database
    df.to_sql(f'data/{table}', index=False)

def tidy_player_info(mydict, delete_keys):
    '''Remove keys from dictionary item that certain keys that do not want to be written to database'''

    keys_to_remove = set(delete_keys).intersection(set(mydict.keys()))
    for key in keys_to_remove:
        del mydict[key]

    return mydict

def clean_player_details(data):
    '''
    Cleans data format for player details data.
    '''
    
    player_info = {}

    for key, value in data.items():
        
        if key == 'Date of Birth':
            # get birthday in better format
            value = get_birthday(value)
            player_info['_'.join(key.lower().split(' '))] = value
            
        elif key == 'Height':
            value = get_height(value)
            player_info['_'.join(key.lower().split(' '))] = value
            
        elif key == 'Weight':
            value = get_weight(value)
            player_info['_'.join(key.lower().split(' '))] = value
            
            
        elif key == 'NHL Rights':
            player_info = {**player_info, **get_team_rights(value)}

        elif key == 'Drafted':
            player_info['draft_year'] = get_draft_year(value)
            player_info['draft_round'] = get_draft_round(value)
            player_info['draft_pick'] = get_draft_pick(value)
            player_info['draft_team'] = get_draft_team(value)
        
        else:
            player_info['_'.join(key.lower().split(' '))] = value
            
    return player_info

def get_draft_year(string):
    '''Using regular expression to return year a player was drafted from table row'''

    try:
        return re.split('[ ]', string)[0]
    except:
        return np.nan

def get_draft_round(string):
    '''Using regular expression to return round a player was drafted from table row'''

    try:
        return re.split('[ ]', string)[2]
    except:
        return np.nan

def get_draft_pick(string):
    '''Using regular expression to return the pick position a player was drafted from table row'''

    try:
        return re.split('[ ]', string)[3].strip('#')
    except:
        return np.nan

def get_draft_team(string):
    '''Using regular expression to return the team a player was drafted from table row'''

    try:
        return re.split('by', string)[1].strip()
    except:
        return np.nan

def get_team_rights(string):
    '''Using regular expression to return the current player rights from table row'''

    try:
        team, signed = string.split(' / ')
        return dict(rights=team, under_contract=True if signed == 'Signed' else False)
    except:
        return np.nan

def get_height(string):
    '''Using regular expression to return height in centimeter from table row'''

    try:
        return int(re.split('[/]', string)[1].strip('cm').strip())
    except:
        return np.nan

def get_weight(string):
    '''Using regular expression to return weight in kilograms from table row'''

    try:
        return int(re.split('[/]', string)[1].strip('kg').strip())
    except:
        return np.nan

def get_birthday(string):
    '''Using regular expression to extract player birthday from player url'''

    try:
        return datetime.datetime.strptime(string, "%b %d, %Y").strftime("%Y-%m-%d")
    except:
        return ''

def get_teamids(links):
    '''Using regular expression to return teamid from team url'''

    try:
        return [l.split('/')[4] for l in links]
    except:
        return ''

def get_shorthands(links):
    '''Using regular expression to return shorthands from url'''

    try:
        return [l.split('/')[5] for l in links]
    except:
        return ''

def get_playerids(links):
    '''Using regular expression to return playerid from player url'''

    try:
        return [l.split('/')[4] for l in links]
    except:
        return ''

def get_position(s):
    '''Using regular expression to return playerid from player url'''

    try:
        return re.search('\(([^)]+)', s).group(1).split('/')
    except:
        return ''

def clean_player_name(name):
    '''Using regular expression to return player name from table row'''

    return name[:np.negative(len(re.search('\(([^)]+)', name).group(1)) + 2)].strip()

def get_basic_player_info(soup):
    '''This function finds player details div and loops over the line items
    and creates a key/value dictionary containing player basic information'''
    
    player_details = soup.find('div', class_ = 'ep-list')
    main_details = player_details.find_all('div', class_='col-xs-12')
    player_info = {k.text.strip() : v.text.replace('\n','').strip().strip() for k,v in zip(main_details[0::2], main_details[1::2])}

    player_info = clean_player_details(player_info)

    return player_info

def get_add_player_info(soup, player_info):
    '''This function finds player details unlisted div and loops over the line items
    and creates a key/value dictionary containing player additional information. Returns
    a merged dictionary of basic player info and additional player info.'''

    # additional info in unlisted list
    add_info = soup.find('section', class_='plyr_details').find_all('ul', class_ = 'list-unstyled')

    # interate over div to get draft information and signed status if exists
    draft_info = {}
    for list_ in add_info:
        for info in list_.find_all('li'):
            if info.find('div', class_='col-xs-3 fac-lbl-light'):
                key = info.find('div', class_='col-xs-3 fac-lbl-light').text.replace('\n','').strip()
                value = info.find('div', class_='col-xs-9 fac-lbl-dark').text.replace('\n','').strip()

                draft_info['_'.join(key.lower().split(' '))] = value

            if 'nhl_rights' in draft_info:
                draft_info = {**draft_info, **get_team_rights(draft_info['nhl_rights'])}
            if 'drafted' in draft_info:
                draft_info = {**draft_info, **get_draft_year(draft_info['drafted'])}
                draft_info = {**draft_info, **get_draft_round(draft_info['drafted'])}
                draft_info = {**draft_info, **get_draft_pick(draft_info['drafted'])}
                draft_info = {**draft_info, **get_draft_team(draft_info['drafted'])}

    return {**player_info, **draft_info}

def get_team_league_stats(league, year):
    '''This function takes a league name and year and retrieves standings and team stats. 
    Returns standings, teamidis and team shorthands to retrieve player roster information.'''
    # find current season
    current_season = get_current_year(datetime.date.today())

    # contruct url
    league_path = '-'.join(league.lower().split(' '))
    url = f'{base_url}/league/{league_path}/{year}'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, features="lxml")

    # get standings
    standings = soup.find('table', {'class': 'table standings table-sortable'})

    team_links = [] # hyperlinks
    columns = ['team', 'gp', 'w', 't', 'l', 'otw',
               'otl', 'gf', 'ga', 'gd', 'tp'] # columns to return
    # get all rows for table
    table_rows = standings.find_all('tr')
    data = []
    for tr in table_rows:
        rows = []
        td = tr.find_all('td')
        # check if there are post season / playout / relegation stats
        if tr.attrs:
            if tr['class'][0] == 'title':
                header = tr.text.replace('\n','').strip()
                if header in ['Playout', 'Relegation']:
                    break
            
        for t in td:     
            try:
                if t['class'][0] in columns:
                    # if there is a link find the hyperlinks
                    if t.find('a'):
                        team_links.append(t.find('a').get('href'))
                    rows.append(t.text.replace('\n',''))
            except:
                # only add data that are contained in columns or have a class
                continue

        data.append(rows)

    team_standings = pd.DataFrame(data, columns=columns).dropna().replace(
        {'-': np.nan}).replace({'': np.nan}).replace({' - ': np.nan}).fillna(0)

    team_standings = team_standings.apply(pd.to_numeric, errors="ignore")
    # get team ids from url
    teamids = get_teamids(team_links)
    # get lowercase/hyphenated team name from url
    teamshorts = get_shorthands(team_links)
    # check team urls for current season
    if len(team_links[0].split('/')) != 7:
        team_links = [l + f'/{current_season}' for l in team_links]

    # add as metadata keys to df
    team_standings['season'] = year
    team_standings['teamid'] = teamids
    team_standings['shortname'] = teamshorts
    team_standings['url'] = team_links
    team_standings['league'] = league
    
    # aggregate regular season stats
    team_standings = team_standings.groupby(
        ['team', 'teamid', 'season', 'shortname', 'league', 'url']).sum().reset_index()

    return team_standings, team_standings.teamid, team_standings.shortname

def get_skater_stats(soup, year, teamid, teamshort, league):
    '''This function takes a teamid, team name and year and retrieves team skater stats. 
    Returns skater scoring data after calculating basic metrics.'''

    stats_table = soup.find('table',
                            {'class': 'table table-striped table-sortable skater-stats highlight-stats'})
    columns = ['season_stage', 'player', 'gp', 'g', 'a', 'tp', 'pim', 'pm']
    player_links = []

    # get all table rows from html table div minus title
    table_rows = stats_table.find_all('tr')[1:]
#     headers = set(stats_table.find_all('tr', class_ = ['title']))
#     table_rows -= headers

    data = []
    for tr in table_rows:
        # only retrieve regular season stats
        if tr.attrs:
            if 'class' in tr.attrs.keys():
                if tr['class'][0] == 'title':
                    header = tr.text.replace('\n','').strip()
                    if header != league and header[-1] != league:
                        season_stage = header
                        continue # don't want to add header to list of player stats
                    else:
                        season_stage = "Regular Season"
                        continue # don't want to add header to list of player stats
                    
        rows = [season_stage]
        td = tr.find_all('td')
        for t in td:
            try:
                if t['class'][0] in columns:
                    # if there is a link find the hyperlinks
                    if t.find('a'):
                        player_links.append(t.find('a').get('href'))
                    rows.append(t.text.replace('\n','').strip())
            except:
                # only add data that are contained in columns or have a class
                continue

        data.append(rows)

    # create dataframe for data
    player_stats = pd.DataFrame(data, columns=columns).dropna() # drop empty values
    player_stats = player_stats[player_stats.player != ''] # empty string players entries
    player_stats = player_stats.replace(
        {'-': np.nan}).replace({'': np.nan}).fillna(0).apply(pd.to_numeric, errors="ignore")

    # clean up dataframe -- add position, playerid, team info
    player_stats['position'] = player_stats.player.apply(get_position)
    player_stats['player'] = player_stats.player.apply(clean_player_name)
    player_stats['team'] = teamshort[:3].upper()
    player_stats['teamid'] = teamid
    player_stats['playerid'] = get_playerids(player_links)
    player_stats['year'] = year
    player_stats['url'] = player_links
    player_stats['shortname'] = get_shorthands(player_links)
    # calculate metrics for players
    player_stats = player_stats.groupby(['season_stage']).apply(calculate_player_metrics)

    return player_stats.droplevel(0)

def get_goalie_stats(soup, year, teamid, teamshort, league):
    '''This function takes a teamid, team name and year and retrieves team goalie stats. 
    Returns goalie scoring data.'''

    stats_table = soup.find('table',
                            {'class': 'table table-striped table-sortable goalie-stats highlight-stats'})
    columns = ['season_stage', 'player', 'gp', 'gaa', 'svp']

    goalie_links = []

    # get all table rows from html table div minus title
    table_rows = stats_table.find_all('tr')[1:]
#     headers = set(stats_table.find_all('tr', class_ = ['title']))
#     table_rows -= headers

    data = []
    for tr in table_rows:
        # only retrieve regular season stats
        if tr.attrs:
            if 'class' in tr.attrs.keys():
                if tr['class'][0] == 'title':
                    header = tr.text.replace('\n','').strip()
                    if header != league and header[-1] != league:
                        season_stage = header
                        continue # don't want to add header to list of player stats
                    else:
                        season_stage = "Regular Season"
                        continue # don't want to add header to list of player stats
                    
        rows = [season_stage]
        td = tr.find_all('td')
        for t in td:
            try:
                if t['class'][0] in columns:
                    # if there is a link find the hyperlinks
                    if t.find('a'):
                        goalie_links.append(t.find('a').get('href'))
                    rows.append(t.text.replace('\n','').strip())
            except:
                # only add data that are contained in columns or have a class
                continue

        data.append(rows)

    # create dataframe for data
    goalie_stats = pd.DataFrame(data, columns=columns).dropna() # drop empty values
    goalie_stats = goalie_stats[goalie_stats.player != ''] # empty string players entries
    goalie_stats = goalie_stats.replace(
    {'-': np.nan}).replace({'': np.nan}).fillna(0).apply(pd.to_numeric, errors="ignore")

    goalie_stats['team'] = teamshort[:3].upper()
    goalie_stats['teamid'] = teamid
    goalie_stats['playerid'] = get_playerids(goalie_links)
    goalie_stats['year'] = year
    goalie_stats['url'] = goalie_links
    goalie_stats['shortname'] = get_shorthands(goalie_links)

    return goalie_stats

def get_player_stats(year, teamid, teamshort, league):
    '''This function takes a teamid, team name and year and retrieves team goalie and skater stats. 
    Returns goalie / skater scoring data as a wrapper around individual position functions.'''

    # contruct url
    url = f'{base_url}/team/{teamid}/{teamshort}/{year}?tab=stats#players'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, features="lxml")

#     try:
        # get stats from goalies and skaters
    return get_skater_stats(soup, year, teamid, teamshort, league), get_goalie_stats(soup, year, teamid, teamshort, league)

#     except:
#         print(f'\n{year} {teamshort} does not have have proper team stats \n')
#         return pd.DataFrame(columns=['player', 'gp', 'g',
#                                      'a', 'tp', 'pim', 'pm']), pd.DataFrame(columns=['player', 'gp',
#                                                                                      'gaa', 'svp'])

def calculate_player_metrics(df):
    '''Takes a dataframe containing player stats for a team and calcuates metrics intra-team.
    Returns points per game, assists per game, goals per game, percent of team points, etc.
    '''
    try:
        # adding metrics
        df = df.assign(
            gpg=(df.g.astype(int) / df.gp.astype(int)).round(3),
            apg=(df.a.astype(int) / df.gp.astype(int)).round(3),
            ppg=(df.tp.astype(int) / df.gp.astype(int)).round(3),
            perc_team_g=((df.g.astype(int) / df.gp) / (df.g.astype(int).sum() / df.gp.max())).round(3),
            perc_team_a=((df.a.astype(int) / df.gp) / (df.a.astype(int).sum() / df.gp.max())).round(3),
            perc_team_tp=((df.tp.astype(int) / df.gp) / (df.tp.astype(int).sum() / df.gp.max())).round(3))

        return df

    except:
        
        return df

def scrape_league_season_stats(league, year):
    '''This function is a wrapper takes a league name and year and retrieve team league
    standings data, skater scoring statistics, traditional goalie statistics. 
    '''

    print(f'\n--- Getting League Team Stats for {league} {year} --- \n')
    league_player_stats = []
    league_goalie_stats = []
    # get league standings for teams
    team_standings, teamids, teamshorts = get_team_league_stats(league, year)

    # loop over teams to construct player stat tables
    for teamid, teamshort in zip(teamids, teamshorts):
        try:
            print(f'--- Getting Team Player Stats for {teamshort} {teamid} ---')
            player_stats, goalie_stats = get_player_stats(year, teamid, teamshort, league)

            league_player_stats.append(player_stats)
            league_goalie_stats.append(goalie_stats)
            # space url calls by 1 second each time
            time.sleep(2)
        except:
            print(f'\n--- Failed to load {teamshort} {teamid} ---')
            continue

    player_stats = pd.concat(league_player_stats, sort=False)
    goalie_stats = pd.concat(league_goalie_stats, sort=False)

    player_stats = player_stats.assign(league=league)
    goalie_stats = goalie_stats.assign(league=league)

    return team_standings, player_stats, goalie_stats

def get_player_info(playerid, shortname):
    ''' This function takes a playerid and player shortname and retrieve all scrapable 
    player information from their player page.
    '''

    print(f'--- Retrieving player info for: {shortname}')

    url = f'{base_url}/player/{playerid}/{shortname}'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, features="lxml")

    delete_keys = ['age', 'youth_team', 'agency', 'highlights',
                   'drafted', 'cap_hit', 'nhl_rights']

    player_info = get_basic_player_info(soup)
    player_info = tidy_player_info(player_info, delete_keys)

    player_info = pd.DataFrame([player_info])
    player_info['date_of_birth'] = pd.to_datetime(player_info['date_of_birth'])
    player_info['playerid'] = playerid
    player_info['shortname'] = shortname
    
    # space url calls by 1 second each time
    time.sleep(4)
    
    return player_info

def full_data_load(output='csv'):
    '''This function is the main wrapper for a full load of elite prospects data. Leagues and Years
    are initialized, then looped over to retrieve team league standings, skater/goalie statistics and
    player information. Will always return a CSV output of the 4 main files and also has functionality 
    to update tables in a postgres database.
    '''

    # get date time of when script starts
    start = time.time()

    # initialize lists to hold data frames
    team_stats = []
    player_stats = []
    goalie_stats = []
    player_info = []

    for league in leagues:
        for year in seasons:
            try:
                # get team, skaters & goalies stats from league page
                teams, players, goalies = scrape_league_season_stats(league, year)
                team_stats.append(teams)
                player_stats.append(players)
                goalie_stats.append(goalies)

                # write data to database after each league season loaded
#                 if output == 'postgres':
#                     output_to_db(teams, 'team_standing')
#                     output_to_db(players, 'skaters')
#                     output_to_db(goalies, 'goalies')

            except Exception as e:
                print(f'\n---{league} {year} not found---\n')
                print(e)
                continue

    team_stats = pd.concat(team_stats, sort=False)
    player_stats = pd.concat(player_stats, sort=False)
    goalie_stats = pd.concat(goalie_stats, sort=False)
    # get player info for skaters and goalies
    players = get_unique_players(player_stats, goalie_stats)

    for playerid, shortname in zip(players.playerid, players.shortname):
        try:
            player = get_player_info(playerid, shortname)
            player_info.append(player)
        except:
            print(f'--- {shortname} bad player data ---')
            continue
    
    player_info = pd.concat(player_info, sort=False)
    # gets draft eligibility for all players
    player_info = get_draft_eligibility(player_info)

#     if output == 'postgres':
#         output_to_db(player_info, 'player_info')

    # output to csv always
    output_to_csv(team_stats, 'team_standing')
    output_to_csv(player_stats, 'skaters')
    output_to_csv(goalie_stats, 'goalies')
    output_to_csv(player_info, 'player_info')

    print('Runtime : {} mins'.format(round((time.time() - start) / 60 ,2)))

def main(output):
    full_data_load(output)

# %%
full_data_load()
# Out:
# --- Getting League Team Stats for CCHL2 2005-2006 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# /Users/connorjung/.pyenv/versions/apple/lib/python3.7/site-packages/ipykernel_launcher.py:515: RuntimeWarning: invalid value encountered in long_scalars
# /Users/connorjung/.pyenv/versions/apple/lib/python3.7/site-packages/ipykernel_launcher.py:516: RuntimeWarning: invalid value encountered in long_scalars
# /Users/connorjung/.pyenv/versions/apple/lib/python3.7/site-packages/ipykernel_launcher.py:517: RuntimeWarning: invalid value encountered in long_scalars
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-kings 8670 ---
#
# --- Failed to load carleton-place-kings 8670 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-beavers 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for kemptville-73-s 4349 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
#
# --- Failed to load metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
#
# --- Failed to load perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
#
# --- Failed to load renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
#
# --- Failed to load shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for south-ottawa-canadians 7155 ---
#
# --- Failed to load south-ottawa-canadians 7155 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# /Users/connorjung/.pyenv/versions/apple/lib/python3.7/site-packages/ipykernel_launcher.py:515: RuntimeWarning: invalid value encountered in true_divide
# /Users/connorjung/.pyenv/versions/apple/lib/python3.7/site-packages/ipykernel_launcher.py:516: RuntimeWarning: invalid value encountered in true_divide
# /Users/connorjung/.pyenv/versions/apple/lib/python3.7/site-packages/ipykernel_launcher.py:517: RuntimeWarning: invalid value encountered in true_divide
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2006-2007 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-kings 8670 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for kemptville-73-s 4349 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for south-ottawa-canadians 7155 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2007-2008 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-kings 8670 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2008-2009 ---
#
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-kings 8670 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2009-2010 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for almonte-thunder 6289 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for ganonoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2010-2011 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for almonte-thunder 6289 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2011-2012 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for almonte-thunder 6289 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for stittvsille-roylas 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2012-2013 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for almonte-thunder 6289 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for south-grenville-rangers 24543 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2013-2014 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for almonte-thunder 6289 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for prescott-flyers 24543 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for stittsville-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2014-2015 ---
#
# --- Getting Team Player Stats for akwesasne-wolves 5684 ---
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for almonte-thunder 6289 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for gananoque-islanders 6240 ---
# --- Getting Team Player Stats for gatineau-mustangs 10381 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for morrisburg-lions 9176 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for prescott-flyers 24543 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for shawville-pontiacs 6344 ---
# --- Getting Team Player Stats for stittsville-rams 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2015-2016 ---
#
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for prescott-flyers 24543 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for stittsville-rams 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2016-2017 ---
#
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for clarence-castors 24541 ---
# --- Getting Team Player Stats for metcalfe-jets 6310 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for prescott-flyers 24543 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for richmond-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2017-2018 ---
#
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-jr.-canadians 24541 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for embrun-panthers 9755 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for richmond-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for whitewater-kings 24543 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2018-2019 ---
#
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-jr.-canadians 24541 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for embrun-panthers 9755 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for richmond-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for whitewater-kings 24543 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for CCHL2 2019-2020 ---
#
# --- Getting Team Player Stats for alexandria-glens 6623 ---
# --- Getting Team Player Stats for arnprior-packers 6848 ---
# --- Getting Team Player Stats for athens-aeros 3518 ---
# --- Getting Team Player Stats for brockville-tikis 5683 ---
# --- Getting Team Player Stats for carleton-place-jr.-canadians 24541 ---
# --- Getting Team Player Stats for casselman-vikings 6354 ---
# --- Getting Team Player Stats for char-lan-rebels 6851 ---
# --- Getting Team Player Stats for embrun-panthers 9755 ---
# --- Getting Team Player Stats for ottawa-jr.-canadians 7155 ---
# --- Getting Team Player Stats for ottawa-west-golden-knights 6850 ---
# --- Getting Team Player Stats for perth-blue-wings 6846 ---
# --- Getting Team Player Stats for renfrew-timberwolves 6434 ---
# --- Getting Team Player Stats for richmond-royals 6849 ---
# --- Getting Team Player Stats for westport-rideaus 9701 ---
# --- Getting Team Player Stats for whitewater-kings 24543 ---
# --- Getting Team Player Stats for winchester-hawks 5867 ---
#
# --- Getting League Team Stats for NHL 2005-2006 ---
#
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for mighty-ducks-of-anaheim 1580 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2006-2007 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2007-2008 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2008-2009 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2009-2010 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2010-2011 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2011-2012 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2012-2013 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2013-2014 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2014-2015 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2015-2016 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2016-2017 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2017-2018 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for vegas-golden-knights 22211 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2018-2019 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for vegas-golden-knights 22211 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2019-2020 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for vegas-golden-knights 22211 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NLA 2005-2006 ---
#
# --- Getting Team Player Stats for ehc-basel 258 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# ...
# --- Retrieving player info for: vincent-hessler
# --- Retrieving player info for: david-zucker
# --- Retrieving player info for: steve-slaton
# --- Retrieving player info for: marius-stober
# --- Retrieving player info for: alexander-karachun
# --- Retrieving player info for: noureddine-bettahar
# --- Retrieving player info for: finn-walkowiak
# --- Retrieving player info for: lois-spitzner
# --- Retrieving player info for: philipp-kuhnekath
# --- Retrieving player info for: valentin-busch
# --- Retrieving player info for: yannick-kischer
# --- Retrieving player info for: nikolaus-hartl
# --- Retrieving player info for: phil-hungerecker
# --- Retrieving player info for: alex-lambacher
# --- Retrieving player info for: pierre-preto
# --- Retrieving player info for: marco-sternheimer
# --- Retrieving player info for: nicolas-strodel
# --- Retrieving player info for: tobias-eder
# --- Retrieving player info for: pascal-grosse
# --- Retrieving player info for: dennis-swinnen
# --- Retrieving player info for: darren-mieszkowski
# --- Retrieving player info for: lucas-dumont
# --- Retrieving player info for: eric-valentin
# --- Retrieving player info for: dominik-bohac
# --- Retrieving player info for: samuel-soramies
# --- Retrieving player info for: louis-brune
# --- Retrieving player info for: stefan-reiter
# --- Retrieving player info for: justin-schutz
# --- Retrieving player info for: dennis-lobach
# --- Retrieving player info for: philipp-wachter
# --- Retrieving player info for: tim-wohlgemuth
# --- Retrieving player info for: eric-mik
# --- Retrieving player info for: fedor-kolupaylo
# --- Retrieving player info for: steven-raabe
# --- Retrieving player info for: jakob-ceglarski
# --- Retrieving player info for: julian-lautenschlager
# --- Retrieving player info for: phillip-bruggisser
# --- Retrieving player info for: martin-lefebvre
# --- Retrieving player info for: edwin-schitz
# --- Retrieving player info for: robin-palka
# --- Retrieving player info for: simon-gnyp
# --- Retrieving player info for: huba-sekesi
# --- Retrieving player info for: yannick-wenzel
# --- Retrieving player info for: martin-stajnoch
# --- Retrieving player info for: maximilian-kolb
# --- Retrieving player info for: julian-kornelli
# --- Retrieving player info for: daniel-schwamberger
# --- Retrieving player info for: daniel-pfaffengut
# --- Retrieving player info for: boaz-bassen
# --- Retrieving player info for: christian-bauhof
# --- Retrieving player info for: tim-stutzle
# --- Retrieving player info for: valentino-klos
# --- Retrieving player info for: moritz-wirth
# --- Retrieving player info for: niklas-langer
# --- Retrieving player info for: nicolas-geitner
# --- Retrieving player info for: alexander-ehl
# --- Retrieving player info for: alexander-dersch
# --- Retrieving player info for: john-jason-peterka
# --- Retrieving player info for: luca-zitterbart
# --- Retrieving player info for: filip-varejcka
# --- Retrieving player info for: bastian-eckl
# --- Retrieving player info for: garret-pruden
# --- Retrieving player info for: lukas-reichel
# --- Retrieving player info for: fabian-dietz
# --- Retrieving player info for: thomas-reichel
# --- Retrieving player info for: stanislav-dietz
# --- Retrieving player info for: tomas-sykora
# --- Retrieving player info for: luca-glaser
# --- Retrieving player info for: tom-horschel
# --- Retrieving player info for: jan-nijenhuis
# --- Retrieving player info for: erik-buschmann
# --- Retrieving player info for: tobias-schmitz
# --- Retrieving player info for: alexander-blank
# --- Retrieving player info for: arturs-kruminsch
# --- Retrieving player info for: maximilian-glotzl
# --- Retrieving player info for: markus-lillich
# --- Retrieving player info for: tim-bernhardt
# --- Retrieving player info for: maximilian-hadraschek
# --- Retrieving player info for: david-cerny
# --- Retrieving player info for: tim-brunnhuber
# --- Retrieving player info for: marco-ba%C3%9Fler
# --- Retrieving player info for: miroslav-lazo
# --- Retrieving player info for: peter-bartos
# --- Retrieving player info for: jaroslav-kmit
# --- Retrieving player info for: juraj-kledrowetz
# --- Retrieving player info for: ludek-krayzel
# --- Retrieving player info for: jan-lipiansky
# --- Retrieving player info for: lubomir-sabol
# --- Retrieving player info for: lukas-hvila
# --- Retrieving player info for: richard-jencik
# --- Retrieving player info for: marcel-simurda
# --- Retrieving player info for: michal-lukac
# --- Retrieving player info for: milan-varga
# --- Retrieving player info for: martin-slovak
# --- Retrieving player info for: jan-horacek
# --- Retrieving player info for: marek-topoli
# --- Retrieving player info for: stanislav-kall
# --- Retrieving player info for: peter-fruhauf
# --- Retrieving player info for: frantisek-bombic
# --- Retrieving player info for: jaroslav-spelda
# --- Retrieving player info for: jaroslav-torok
# --- Retrieving player info for: miroslav-vantroba
# --- Retrieving player info for: tomas-bulik
# --- Retrieving player info for: tomas-zagyi
# --- Retrieving player info for: pavel-valko
# --- Retrieving player info for: lubomir-caban
# --- Retrieving player info for: lubomir-chmelo
# --- Retrieving player info for: slavomir-bodnar
# --- Retrieving player info for: peter-klouda
# --- Retrieving player info for: rene-skoliak
# --- Retrieving player info for: radim-kucharczyk
# --- Retrieving player info for: lubomir-pistek
# --- Retrieving player info for: daniel-hancak
# --- Retrieving player info for: juraj-prokop
# --- Retrieving player info for: kristian-kovac
# --- Retrieving player info for: martin-kulha
# --- Retrieving player info for: miroslav-durak
# --- Retrieving player info for: radoslav-hecl
# --- Retrieving player info for: juraj-sykora
# --- Retrieving player info for: petr-pavlas
# --- Retrieving player info for: branislav-janos
# --- Retrieving player info for: dusan-pasek
# --- Retrieving player info for: david-kudelka
# --- Retrieving player info for: peter-junas
# --- Retrieving player info for: radovan-sloboda
# --- Retrieving player info for: karol-sloboda
# --- Retrieving player info for: rudolf-jendek
# --- Retrieving player info for: martin-hujsa
# --- Retrieving player info for: tomas-nemcicky
# --- Retrieving player info for: zdeno-ciger
# --- Retrieving player info for: ivan-dornic
# --- Retrieving player info for: tomas-chlubna
# --- Retrieving player info for: denis-afinogenov
# --- Retrieving player info for: petr-mika
# --- Retrieving player info for: vladimir-gyna
# --- Retrieving player info for: dusan-devecka
# --- Retrieving player info for: robin-just
# --- Retrieving player info for: jozef-wagenhoffer
# --- Retrieving player info for: darius-rusnak
# --- Retrieving player info for: lukas-pek
# --- Retrieving player info for: milan-balis
# --- Retrieving player info for: tomas-spila
# --- Retrieving player info for: petr-buzek
# --- Retrieving player info for: tibor-varga
# --- Retrieving player info for: marcel-ulehla
# --- Retrieving player info for: jan-kopecky
# --- Retrieving player info for: robert-huna
# --- Retrieving player info for: jan-sebo
# --- Retrieving player info for: richard-huna
# --- Retrieving player info for: martin-kriska
# --- Retrieving player info for: marek-hovorka
# --- Retrieving player info for: stanislav-fatyka
# --- Retrieving player info for: peter-listiak
# --- Retrieving player info for: martin-trochta
# --- Retrieving player info for: richard-zemlicka
# --- Retrieving player info for: miroslav-droppa
# --- Retrieving player info for: igor-rufus
# --- Retrieving player info for: jan-pleva
# --- Retrieving player info for: peter-bartik
# --- Retrieving player info for: gabriel-kover
# --- Retrieving player info for: martin-opatovsky
# --- Retrieving player info for: branislav-pohanka
# --- Retrieving player info for: tomas-kratky
# --- Retrieving player info for: miroslav-taragel
# --- Retrieving player info for: michal-skoliak
# --- Retrieving player info for: michal-mravec
# --- Retrieving player info for: marcel-sterbak
# --- Retrieving player info for: stefan-bohucky
# --- Retrieving player info for: peter-misal
# --- Retrieving player info for: pavol-segla
# --- Retrieving player info for: michal-grman
# --- Retrieving player info for: tomas-valecko
# --- Retrieving player info for: pavol-milec
# --- Retrieving player info for: juraj-kadlubiak
# --- Retrieving player info for: jan-tomaska
# --- Retrieving player info for: rene-jarolin
# --- Retrieving player info for: richard-hartmann
# --- Retrieving player info for: petr-vala
# --- Retrieving player info for: ales-kretinsky
# --- Retrieving player info for: robert-liscak
# --- Retrieving player info for: tibor-visnovsky
# --- Retrieving player info for: martin-ivicic
# --- Retrieving player info for: roman-sykora
# --- Retrieving player info for: martin-zajac
# --- Retrieving player info for: jozef-liska
# --- Retrieving player info for: marek-grill
# --- Retrieving player info for: boris-flamik
# --- Retrieving player info for: michal-kokavec
# --- Retrieving player info for: milan-malik
# --- Retrieving player info for: roman-mucha
# --- Retrieving player info for: michal-dostal
# --- Retrieving player info for: tomas-klement
# --- Retrieving player info for: martin-krumpal
# --- Retrieving player info for: tomas-hrncirik
# --- Retrieving player info for: tomas-vasko
# --- Retrieving player info for: peter-gula
# --- Retrieving player info for: michal-satek
# --- Retrieving player info for: martin-chovan
# --- Retrieving player info for: martin-holly
# --- Retrieving player info for: michal-hrtus
# --- Retrieving player info for: martin-skadra
# --- Retrieving player info for: lukas-komarek
# --- Retrieving player info for: tibor-melicharek
# --- Retrieving player info for: jan-zlocha
# --- Retrieving player info for: vladimir-nemec
# --- Retrieving player info for: peter-huzevka
# --- Retrieving player info for: peter-poliacek
# --- Retrieving player info for: jaroslav-kona
# --- Retrieving player info for: igor-majesky
# --- Retrieving player info for: jan-homer
# --- Retrieving player info for: peter-mikus
# --- Retrieving player info for: tomas-micka
# --- Retrieving player info for: anton-lezo
# --- Retrieving player info for: juraj-durco
# --- Retrieving player info for: ladislav-sikorcin
# --- Retrieving player info for: vladislav-balaz
# --- Retrieving player info for: slavomir-hrina
# --- Retrieving player info for: vladimir-kutny
# --- Retrieving player info for: juraj-liska
# --- Retrieving player info for: marcel-hanzal
# --- Retrieving player info for: ladislav-gabris
# --- Retrieving player info for: vladimir-urban
# --- Retrieving player info for: patrik-rimmel
# --- Retrieving player info for: david-mocek
# --- Retrieving player info for: richard-lelkes
# --- Retrieving player info for: jozef-mrena
# --- Retrieving player info for: martin-kivon
# --- Retrieving player info for: miroslav-hantak
# --- Retrieving player info for: jiri-hes
# --- Retrieving player info for: marek-ivan
# --- Retrieving player info for: richard-safarik
# --- Retrieving player info for: petr-kuchyna
# --- Retrieving player info for: lubomir-kolnik
# --- Retrieving player info for: tomas-chrenko
# --- Retrieving player info for: andrej-kollar
# --- Retrieving player info for: vladimir-vlk
# --- Retrieving player info for: miroslav-stefanka
# --- Retrieving player info for: andrej-kmec
# --- Retrieving player info for: martin-vozdecky
# --- Retrieving player info for: jozef-mihalik
# --- Retrieving player info for: milan-hruska
# --- Retrieving player info for: viliam-cacho
# --- Retrieving player info for: samir-saliji
# --- Retrieving player info for: boris-majesky
# --- Retrieving player info for: mojmir-musil
# --- Retrieving player info for: jozef-kovacik
# --- Retrieving player info for: albin-podstavek
# --- Retrieving player info for: garip-saliji
# --- Retrieving player info for: miroslav-pupak
# --- Retrieving player info for: martin-petrina
# --- Retrieving player info for: marian-scheibenreif
# --- Retrieving player info for: juraj-cebak
# --- Retrieving player info for: lubomir-strapko
# --- Retrieving player info for: arne-krotak
# --- Retrieving player info for: slavomir-pavlicko
# --- Retrieving player info for: juraj-halaj
# --- Retrieving player info for: juraj-faith
# --- Retrieving player info for: miroslav-javin
# --- Retrieving player info for: richard-jasovsky
# --- Retrieving player info for: viktor-kubenko
# --- Retrieving player info for: michal-segla
# --- Retrieving player info for: miroslav-turan
# --- Retrieving player info for: stefan-fabian
# --- Retrieving player info for: pavol-zavacky
# --- Retrieving player info for: pavel-kumstat
# --- Retrieving player info for: slavomir-vorobel
# --- Retrieving player info for: martin-segla
# --- Retrieving player info for: erik-piatak
# --- Retrieving player info for: lukas-bambuch
# --- Retrieving player info for: marcel-hascak
# --- Retrieving player info for: marek-maslonka
# --- Retrieving player info for: pavol-gurcik
# --- Retrieving player info for: richard-kopkas
# --- Retrieving player info for: tomas-smolka
# --- Retrieving player info for: robert-cikovsky
# --- Retrieving player info for: jan-marcinko
# --- Retrieving player info for: martin-tomasek
# --- Retrieving player info for: erik-weissmann
# --- Retrieving player info for: richard-sechny
# --- Retrieving player info for: daniel-babka
# --- Retrieving player info for: filip-turek
# --- Retrieving player info for: jan-cibula
# --- Retrieving player info for: vlastimil-plavucha
# --- Retrieving player info for: rastislav-stork
# --- Retrieving player info for: jozef-cierny
# --- Retrieving player info for: ladislav-paciga
# --- Retrieving player info for: rastislav-gaspar
# --- Retrieving player info for: vitezslav-skuta
# --- Retrieving player info for: tomas-skvaridlo
# --- Retrieving player info for: lubos-velebny
# --- Retrieving player info for: michal-beran
# --- Retrieving player info for: peter-klepac
# --- Retrieving player info for: marek-priechodsky
# --- Retrieving player info for: kamil-mahdalik
# --- Retrieving player info for: jan-simcik
# --- Retrieving player info for: michal-chovan
# --- Retrieving player info for: lukas-jurik
# --- Retrieving player info for: matus-hanes
# --- Retrieving player info for: jozef-voskar
# --- Retrieving player info for: robert-stancok
# --- Retrieving player info for: ladislav-harabin
# --- Retrieving player info for: michal-dian
# --- Retrieving player info for: julius-malcek
# --- Retrieving player info for: filip-macejka
# --- Retrieving player info for: michal-krupa
# --- Retrieving player info for: erik-urgela
# --- Retrieving player info for: adam-kostal
# --- Retrieving player info for: david-hilser
# --- Retrieving player info for: marian-filo
# --- Retrieving player info for: martin-liptak
# --- Retrieving player info for: peter-lalka
# --- Retrieving player info for: patrik-scibran
# --- Retrieving player info for: martin-kubaliak
# --- Retrieving player info for: michal-vazan
# --- Retrieving player info for: ivan-kolozvary
# --- Retrieving player info for: juraj-kuric
# --- Retrieving player info for: marek-kolba
# --- Retrieving player info for: matus-chrenko
# --- Retrieving player info for: tomas-pokrivcak
# --- Retrieving player info for: branislav-stolarik
# --- Retrieving player info for: stanislav-simo
# --- Retrieving player info for: stefan-zachar
# --- Retrieving player info for: peter-holecko
# --- Retrieving player info for: henrich-beutel
# --- Retrieving player info for: miroslav-ihnacak
# --- Retrieving player info for: peter-tabacek
# --- Retrieving player info for: dusan-chromy
# --- Retrieving player info for: lubos-zetik
# --- Retrieving player info for: peter-michnac
# --- Retrieving player info for: martin-ratveisky
# --- Retrieving player info for: peter-ucnik
# --- Retrieving player info for: marek-themar
# --- Retrieving player info for: michal-smrek
# --- Retrieving player info for: martin-ondrej
# --- Retrieving player info for: andrej-themar
# --- Retrieving player info for: rastislav-bohme
# --- Retrieving player info for: pavel-augusta
# --- Retrieving player info for: lukas-bokros
# --- Retrieving player info for: vladimir-konopka
# --- Retrieving player info for: tomas-psenka
# --- Retrieving player info for: filip-simka
# --- Retrieving player info for: roman-kontsek
# --- Retrieving player info for: robert-krajci
# --- Retrieving player info for: michal-hreus
# --- Retrieving player info for: martin-galik
# --- Retrieving player info for: vaclav-kral
