# %%
from dateutil.relativedelta import relativedelta
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import datetime
import argparse
import time
import re
import os

# %%
from dateutil.relativedelta import relativedelta
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import datetime
import argparse
import time
import re
import os

# league names
leagues = ['NHL','NLA','USHL','BCHL', 'SJHL', 'AHL','SuperElit', 'WHL',
           'CCHL','Jr. A SM-liiga','OHL','MHL','SHL','NCAA','Liiga', 
           'Allsvenskan','QMJHL','AJHL','OJHL','KHL','VHL','Czech','Czech2']

# start and end years to scrape data
start_year = 2005
end_year = 2019

# create season labels and get current season
seasons = [f'{s}-{s + 1}' for s in range(start_year, end_year + 1)]

# base url for ep website
base_url = 'https://www.eliteprospects.com'

# output meta data
tables = {
    'team_standing' : {'csv' : 'team_stats.csv',
                       'postgres' : 'team_stats'},
    'skaters' : {'csv' : 'skater_stats.csv',
                 'postgres' : 'skater_stats'},
    'goalies' : {'csv' : 'goalie_stats.csv',
                 'postgres' : 'goalie_stats'},
    'player_info' : {'csv' : 'player_info.csv',
                     'postgres' : 'player_info'},
         }

def get_unique_players(player_stats, goalie_stats):
    '''This function takes skater and goalie stats and returns list of unique 
    dataframe of playerids and player shortnames.
    '''
    player_cols = ['playerid', 'shortname']
    
    players = pd.concat([player_stats[player_cols].drop_duplicates(player_cols),
                         goalie_stats[player_cols].drop_duplicates(player_cols)])
    
    return players

def get_draft_eligibility(df):
    '''Return the first year a player is NHL draft eligible'''

    df.set_index('playerid', inplace=True)

    # create a series filled with valueus of Birth year + 18 on September 15th 
    draft_days = pd.to_datetime(dict(year=df.date_of_birth.dt.year.values + 18,
                        month=np.full((len(df), ), 9),
                        day=np.full((len(df), ), 15))) 

    draft_days.index = df.index

    # check if player will be 18 years old by September 15th of draft year
    df['draft_year_eligible'] = np.where((draft_days - df['date_of_birth']) / np.timedelta64(1, 'Y') >= 18,
                                             df.date_of_birth.dt.year.values + 18,
                                             df.date_of_birth.dt.year.values + 19) 

    return df.reset_index()

def get_current_year(date):
    '''Return hockey season label based on what the current date is'''
    if date.month >= 1 and date.month <= 9:
        return f'{date.year - 1}-{date.year}'

    else:
        return f'{date.year}-{date.year + 1}'

def load_db_credentials():
    '''Load database credentials from bash_profile'''

    user = os.environ['db_user']
    password = os.environ['db_pass']
    server = os.environ['db_host']
    database = os.environ['db_name']
    port = os.environ['db_port']

    return user, password, server, database, port

def output_to_db(df, name):
    '''Writes a dataframe to database using the table metadata outlined at script instantiation'''

    # get db credentials
    user, password, server, database, port = load_db_credentials()
    # create a connection to the database
    engine = create_engine(f'postgresql://{user}:{password}@{server}:{port}/{database}')
    # add a load date field
    df = df.assign(load_date = datetime.date.today())
    # write the values to the database
    df.to_sql(tables[name]['postgres'], engine, if_exists='append', index = False )

def output_to_csv(df, name):
    '''Writes a dataframe to csv file using the table metadata outlined at script instantiation'''
    table = tables[name]['csv']
    # write the values to the database
    df.to_sql(f'data/{table}', index=False)

def tidy_player_info(mydict, delete_keys):
    '''Remove keys from dictionary item that certain keys that do not want to be written to database'''

    keys_to_remove = set(delete_keys).intersection(set(mydict.keys()))
    for key in keys_to_remove:
        del mydict[key]

    return mydict

def get_draft_year(string):
    '''Using regular expression to return year a player was drafted from table row'''

    try:
        return dict(draft_year=re.split('[ ]', string)[0])
    except:
        return np.nan

def get_draft_round(string):
    '''Using regular expression to return round a player was drafted from table row'''

    try:
        return dict(draft_round=re.split('[ ]', string)[2])
    except:
        return np.nan

def get_draft_pick(string):
    '''Using regular expression to return the pick position a player was drafted from table row'''

    try:
        return dict(draft_pick=re.split('[ ]', string)[3].strip('#'))
    except:
        return np.nan

def get_draft_team(string):
    '''Using regular expression to return the team a player was drafted from table row'''

    try:
        return dict(draft_team=re.split('by', string)[1].strip())
    except:
        return np.nan

def get_team_rights(string):
    '''Using regular expression to return the current player rights from table row'''

    try:
        team, signed = string.split(' / ')
        return dict(rights=team, under_contract=True if signed == 'Signed' else False)
    except:
        return np.nan

def get_height(string):
    '''Using regular expression to return height in centimeter from table row'''

    try:
        return int(re.split('[/]', string)[1].strip('cm').strip())
    except:
        return np.nan

def get_weight(string):
    '''Using regular expression to return weight in kilograms from table row'''

    try:
        return int(re.split('[/]', string)[1].strip('kg').strip())
    except:
        return np.nan

def get_birthday(string):
    '''Using regular expression to extract player birthday from player url'''

    try:
        return re.split('[=&]', string)[1]
    except:
        return ''

def get_teamids(links):
    '''Using regular expression to return teamid from team url'''

    try:
        return [l.split('/')[4] for l in links]
    except:
        return ''

def get_shorthands(links):
    '''Using regular expression to return shorthands from url'''

    try:
        return [l.split('/')[5] for l in links]
    except:
        return ''

def get_playerids(links):
    '''Using regular expression to return playerid from player url'''

    try:
        return [l.split('/')[4] for l in links]
    except:
        return ''

def get_position(s):
    '''Using regular expression to return playerid from player url'''

    try:
        return re.search('\(([^)]+)', s).group(1).split('/')
    except:
        return ''

def clean_player_name(name):
    '''Using regular expression to return player name from table row'''

    return name[:np.negative(len(re.search('\(([^)]+)', name).group(1)) + 2)].strip()

def get_basic_player_info(soup):
    '''This function finds player details div and loops over the line items
    and creates a key/value dictionary containing player basic information'''

    player_details = soup.find('div', class_ = 'table-view')
    main_details = player_details.find('div', class_='row')

    player_info = {}

    for details in main_details.find_all('li'):
        key = details.find('div', class_='col-xs-4 fac-lbl-light').text.replace('\n','').strip()
        value = details.find('div', class_='col-xs-8 fac-lbl-dark')
        if (value.find('a')) and (key == 'Date of Birth'):
            # get birthday in better format
            value = get_birthday(value.find('a').get('href'))
        elif key == 'Height':
            value = get_height(value.text.replace('\n','').strip())
        elif key == 'Weight':
            value = get_weight(value.text.replace('\n','').strip())
        else:
            value = value.text.replace('\n','').strip()

        player_info['_'.join(key.lower().split(' '))] = value

    return player_info

def get_add_player_info(soup, player_info):
    '''This function finds player details unlisted div and loops over the line items
    and creates a key/value dictionary containing player additional information. Returns
    a merged dictionary of basic player info and additional player info.'''

    # additional info in unlisted list
    add_info = soup.find('section', class_='plyr_details').find_all('ul', class_ = 'list-unstyled')

    # interate over div to get draft information and signed status if exists
    draft_info = {}
    for list_ in add_info:
        for info in list_.find_all('li'):
            if info.find('div', class_='col-xs-3 fac-lbl-light'):
                key = info.find('div', class_='col-xs-3 fac-lbl-light').text.replace('\n','').strip()
                value = info.find('div', class_='col-xs-9 fac-lbl-dark').text.replace('\n','').strip()

                draft_info['_'.join(key.lower().split(' '))] = value

            if 'nhl_rights' in draft_info:
                draft_info = {**draft_info, **get_team_rights(draft_info['nhl_rights'])}
            if 'drafted' in draft_info:
                draft_info = {**draft_info, **get_draft_year(draft_info['drafted'])}
                draft_info = {**draft_info, **get_draft_round(draft_info['drafted'])}
                draft_info = {**draft_info, **get_draft_pick(draft_info['drafted'])}
                draft_info = {**draft_info, **get_draft_team(draft_info['drafted'])}

    return {**player_info, **draft_info}

def get_team_league_stats(league, year):
    '''This function takes a league name and year and retrieves standings and team stats. 
    Returns standings, teamidis and team shorthands to retrieve player roster information.'''
    # find current season
    current_season = get_current_year(datetime.date.today())

    # contruct url
    league_path = '-'.join(league.lower().split(' '))
    url = f'{base_url}/league/{league_path}/{year}'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, features="lxml")

    # get standings
    standings = soup.find('table', {'class': 'table standings table-sortable'})

    team_links = [] # hyperlinks
    columns = ['team', 'gp', 'w', 't', 'l', 'otw',
               'otl', 'gf', 'ga', 'gd', 'tp'] # columns to return
    # get all rows for table
    table_rows = standings.find_all('tr')
    data = []
    for tr in table_rows:
        rows = []
        td = tr.find_all('td')
        # check if there are post season / playout / relegation stats
        if tr.attrs:
            if tr['class'][0] == 'title':
                header = tr.text.replace('\n','').strip()
                if header in ['Playout', 'Relegation']:
                    break
            
        for t in td:     
            try:
                if t['class'][0] in columns:
                    # if there is a link find the hyperlinks
                    if t.find('a'):
                        team_links.append(t.find('a').get('href'))
                    rows.append(t.text.replace('\n',''))
            except:
                # only add data that are contained in columns or have a class
                continue

        data.append(rows)

    team_standings = pd.DataFrame(data, columns=columns).dropna().replace(
        {'-': np.nan}).replace({'': np.nan}).replace({' - ': np.nan}).fillna(0)

    team_standings = team_standings.apply(pd.to_numeric, errors="ignore")
    # get team ids from url
    teamids = get_teamids(team_links)
    # get lowercase/hyphenated team name from url
    teamshorts = get_shorthands(team_links)
    # check team urls for current season
    if len(team_links[0].split('/')) != 7:
        team_links = [l + f'/{current_season}' for l in team_links]

    # add as metadata keys to df
    team_standings['season'] = year
    team_standings['teamid'] = teamids
    team_standings['shortname'] = teamshorts
    team_standings['url'] = team_links
    team_standings['league'] = league
    
    # aggregate regular season stats
    team_standings = team_standings.groupby(
        ['team', 'teamid', 'season', 'shortname', 'league', 'url']).sum().reset_index()

    return team_standings, team_standings.teamid, team_standings.shortname

def get_skater_stats(soup, year, teamid, teamshort, league):
    '''This function takes a teamid, team name and year and retrieves team skater stats. 
    Returns skater scoring data after calculating basic metrics.'''

    stats_table = soup.find('table',
                            {'class': 'table table-striped table-sortable skater-stats highlight-stats'})
    columns = ['season_stage', 'player', 'gp', 'g', 'a', 'tp', 'pim', 'pm']
    player_links = []

    # get all table rows from html table div minus title
    table_rows = stats_table.find_all('tr')[1:]
#     headers = set(stats_table.find_all('tr', class_ = ['title']))
#     table_rows -= headers

    data = []
    for tr in table_rows:
        # only retrieve regular season stats
        if tr.attrs:
            if 'class' in tr.attrs.keys():
                if tr['class'][0] == 'title':
                    header = tr.text.replace('\n','').strip()
                    if header != league and header[-1] != league:
                        season_stage = header
                        continue # don't want to add header to list of player stats
                    else:
                        season_stage = "Regular Season"
                        continue # don't want to add header to list of player stats
                    
        rows = [season_stage]
        td = tr.find_all('td')
        for t in td:
            try:
                if t['class'][0] in columns:
                    # if there is a link find the hyperlinks
                    if t.find('a'):
                        player_links.append(t.find('a').get('href'))
                    rows.append(t.text.replace('\n','').strip())
            except:
                # only add data that are contained in columns or have a class
                continue

        data.append(rows)

    # create dataframe for data
    player_stats = pd.DataFrame(data, columns=columns).dropna() # drop empty values
    player_stats = player_stats[player_stats.player != ''] # empty string players entries
    player_stats = player_stats.replace(
        {'-': np.nan}).replace({'': np.nan}).fillna(0).apply(pd.to_numeric, errors="ignore")

    # clean up dataframe -- add position, playerid, team info
    player_stats['position'] = player_stats.player.apply(get_position)
    player_stats['player'] = player_stats.player.apply(clean_player_name)
    player_stats['team'] = teamshort[:3].upper()
    player_stats['teamid'] = teamid
    player_stats['playerid'] = get_playerids(player_links)
    player_stats['year'] = year
    player_stats['url'] = player_links
    player_stats['shortname'] = get_shorthands(player_links)
    # calculate metrics for players
    player_stats = player_stats.groupby(['season_stage']).apply(calculate_player_metrics)

    return player_stats.droplevel(0)

def get_goalie_stats(soup, year, teamid, teamshort, league):
    '''This function takes a teamid, team name and year and retrieves team goalie stats. 
    Returns goalie scoring data.'''

    stats_table = soup.find('table',
                            {'class': 'table table-striped table-sortable goalie-stats highlight-stats'})
    columns = ['season_stage', 'player', 'gp', 'gaa', 'svp']

    goalie_links = []

    # get all table rows from html table div minus title
    table_rows = stats_table.find_all('tr')[1:]
#     headers = set(stats_table.find_all('tr', class_ = ['title']))
#     table_rows -= headers

    data = []
    for tr in table_rows:
        # only retrieve regular season stats
        if tr.attrs:
            if 'class' in tr.attrs.keys():
                if tr['class'][0] == 'title':
                    header = tr.text.replace('\n','').strip()
                    if header != league and header[-1] != league:
                        season_stage = header
                        continue # don't want to add header to list of player stats
                    else:
                        season_stage = "Regular Season"
                        continue # don't want to add header to list of player stats
                    
        rows = [season_stage]
        td = tr.find_all('td')
        for t in td:
            try:
                if t['class'][0] in columns:
                    # if there is a link find the hyperlinks
                    if t.find('a'):
                        goalie_links.append(t.find('a').get('href'))
                    rows.append(t.text.replace('\n','').strip())
            except:
                # only add data that are contained in columns or have a class
                continue

        data.append(rows)

    # create dataframe for data
    goalie_stats = pd.DataFrame(data, columns=columns).dropna() # drop empty values
    goalie_stats = goalie_stats[goalie_stats.player != ''] # empty string players entries
    goalie_stats = goalie_stats.replace(
    {'-': np.nan}).replace({'': np.nan}).fillna(0).apply(pd.to_numeric, errors="ignore")

    goalie_stats['team'] = teamshort[:3].upper()
    goalie_stats['teamid'] = teamid
    goalie_stats['playerid'] = get_playerids(goalie_links)
    goalie_stats['year'] = year
    goalie_stats['url'] = goalie_links
    goalie_stats['shortname'] = get_shorthands(goalie_links)

    return goalie_stats

def get_player_stats(year, teamid, teamshort, league):
    '''This function takes a teamid, team name and year and retrieves team goalie and skater stats. 
    Returns goalie / skater scoring data as a wrapper around individual position functions.'''

    # contruct url
    url = f'{base_url}/team/{teamid}/{teamshort}/{year}?tab=stats#players'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, features="lxml")

#     try:
        # get stats from goalies and skaters
    return get_skater_stats(soup, year, teamid, teamshort, league), get_goalie_stats(soup, year, teamid, teamshort, league)

#     except:
#         print(f'\n{year} {teamshort} does not have have proper team stats \n')
#         return pd.DataFrame(columns=['player', 'gp', 'g',
#                                      'a', 'tp', 'pim', 'pm']), pd.DataFrame(columns=['player', 'gp',
#                                                                                      'gaa', 'svp'])

def calculate_player_metrics(df):
    '''Takes a dataframe containing player stats for a team and calcuates metrics intra-team.
    Returns points per game, assists per game, goals per game, percent of team points, etc.
    '''
    try:
        # adding metrics
        df = df.assign(
            gpg=(df.g.astype(int) / df.gp.astype(int)).round(3),
            apg=(df.a.astype(int) / df.gp.astype(int)).round(3),
            ppg=(df.tp.astype(int) / df.gp.astype(int)).round(3),
            perc_team_g=((df.g.astype(int) / df.gp) / (df.g.astype(int).sum() / df.gp.max())).round(3),
            perc_team_a=((df.a.astype(int) / df.gp) / (df.a.astype(int).sum() / df.gp.max())).round(3),
            perc_team_tp=((df.tp.astype(int) / df.gp) / (df.tp.astype(int).sum() / df.gp.max())).round(3))

        return df

    except:
        
        return df

def scrape_league_season_stats(league, year):
    '''This function is a wrapper takes a league name and year and retrieve team league
    standings data, skater scoring statistics, traditional goalie statistics. 
    '''

    print(f'\n--- Getting League Team Stats for {league} {year} --- \n')
    league_player_stats = []
    league_goalie_stats = []
    # get league standings for teams
    team_standings, teamids, teamshorts = get_team_league_stats(league, year)

    # loop over teams to construct player stat tables
    for teamid, teamshort in zip(teamids, teamshorts):
        print(f'--- Getting Team Player Stats for {teamshort} {teamid} ---')
        player_stats, goalie_stats = get_player_stats(year, teamid, teamshort, league)

        league_player_stats.append(player_stats)
        league_goalie_stats.append(goalie_stats)
        # space url calls by 1 second each time
        time.sleep(2)

    player_stats = pd.concat(league_player_stats, sort=False)
    goalie_stats = pd.concat(league_goalie_stats, sort=False)

    player_stats = player_stats.assign(league=league)
    goalie_stats = goalie_stats.assign(league=league)

    return team_standings, player_stats, goalie_stats

def get_player_info(playerid, shortname):
    ''' This function takes a playerid and player shortname and retrieve all scrapable 
    player information from their player page.
    '''

    print(f'--- Retrieving player info for: {shortname}')

    url = f'{base_url}/player/{playerid}/{shortname}'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, features="lxml")

    delete_keys = ['age', 'youth_team', 'agency','highlights', 'position',
                   'drafted', 'cap_hit', 'nhl_rights', 'contract']

    player_info = get_basic_player_info(soup)
    player_info = get_add_player_info(soup, player_info)
    player_info = tidy_player_info(player_info, delete_keys)

    # space url calls by 1 second each time
    time.sleep(3)

    player_info = pd.DataFrame([player_info])
    player_info['date_of_birth'] = pd.to_datetime(player_info['date_of_birth'])
    player_info['playerid'] = playerid
    player_info['shortname'] = shortname

    return player_info

def full_data_load(output='csv'):
    '''This function is the main wrapper for a full load of elite prospects data. Leagues and Years
    are initialized, then looped over to retrieve team league standings, skater/goalie statistics and
    player information. Will always return a CSV output of the 4 main files and also has functionality 
    to update tables in a postgres database.
    '''

    # get date time of when script starts
    start = time.time()

    # initialize lists to hold data frames
    team_stats = []
    player_stats = []
    goalie_stats = []
    player_info = []

    for league in leagues:
        for year in seasons:
            try:
                # get team, skaters & goalies stats from league page
                teams, players, goalies = scrape_league_season_stats(league, year)
                team_stats.append(teams)
                player_stats.append(players)
                goalie_stats.append(goalies)

                # write data to database after each league season loaded
                if output == 'postgres':
                    output_to_db(teams, 'team_standing')
                    output_to_db(players, 'skaters')
                    output_to_db(goalies, 'goalies')

            except:
                print(f'\n---{league} {year} not found---\n')
                continue

    team_stats = pd.concat(team_stats, sort=False)
    player_stats = pd.concat(player_stats, sort=False)
    goalie_stats = pd.concat(goalie_stats, sort=False)
    # get player info for skaters and goalies
    players = get_unique_players(player_stats, goalie_stats)

    for playerid, shortname in zip(players.playerid, players.shortname):
        try:
            player = get_player_info(playerid, shortname)
            player_info.append(player)
        except:
            print(f'--- {shortname} bad player data ---')
            continue
    
    player_info = pd.concat(player_info, sort=False)
    # gets draft eligibility for all players
    player_info = get_draft_eligibility(player_info)

    if output == 'postgres':
        output_to_db(player_info, 'player_info')

    # output to csv always
    output_to_csv(team_stats, 'team_standing')
    output_to_csv(player_stats, 'skaters')
    output_to_csv(goalie_stats, 'goalies')
    output_to_csv(player_info, 'player_info')

    print('Runtime : {} mins'.format(round((time.time() - start) / 60 ,2)))

def main(output):
    full_data_load(output)

# %%
full_data_load('postgres')
# Out:
# --- Getting League Team Stats for NHL 2005-2006 ---
#
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for mighty-ducks-of-anaheim 1580 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2006-2007 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2007-2008 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2008-2009 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2009-2010 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2010-2011 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
#
# --- Getting League Team Stats for NHL 2011-2012 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2012-2013 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2013-2014 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2014-2015 ---
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2015-2016 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2016-2017 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2017-2018 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for vegas-golden-knights 22211 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2018-2019 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for vegas-golden-knights 22211 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NHL 2019-2020 ---
#
# --- Getting Team Player Stats for anaheim-ducks 1580 ---
# --- Getting Team Player Stats for arizona-coyotes 72 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for vegas-golden-knights 22211 ---
# --- Getting Team Player Stats for washington-capitals 78 ---
# --- Getting Team Player Stats for winnipeg-jets 9966 ---
#
# --- Getting League Team Stats for NLA 2005-2006 ---
#
# --- Getting Team Player Stats for ehc-basel 258 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for sc-langnau 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2006-2007 ---
#
# --- Getting Team Player Stats for ehc-basel 258 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for sc-langnau 608 ---
# /Users/connorjung/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:492: RuntimeWarning: invalid value encountered in long_scalars
# /Users/connorjung/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:493: RuntimeWarning: invalid value encountered in long_scalars
# /Users/connorjung/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:494: RuntimeWarning: invalid value encountered in long_scalars
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2007-2008 ---
#
# --- Getting Team Player Stats for ehc-basel 258 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for sc-langnau 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2008-2009 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for sc-langnau 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2009-2010 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2010-2011 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2011-2012 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2012-2013 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2013-2014 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2014-2015 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2015-2016 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for kloten-flyers 112 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2016-2017 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ehc-kloten 112 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2017-2018 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ehc-kloten 112 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2018-2019 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for sc-rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for NLA 2019-2020 ---
#
# --- Getting Team Player Stats for ehc-biel-bienne 918 ---
# --- Getting Team Player Stats for ev-zug 117 ---
# --- Getting Team Player Stats for geneve-servette-hc 260 ---
# --- Getting Team Player Stats for hc-ambri-piotta 107 ---
# --- Getting Team Player Stats for hc-davos 110 ---
# --- Getting Team Player Stats for hc-fribourg-gotteron 111 ---
# --- Getting Team Player Stats for hc-lugano 115 ---
# --- Getting Team Player Stats for lausanne-hc 114 ---
# --- Getting Team Player Stats for sc-bern 108 ---
# --- Getting Team Player Stats for sc-rapperswil-jona-lakers 116 ---
# --- Getting Team Player Stats for scl-tigers 608 ---
# --- Getting Team Player Stats for zsc-lions 118 ---
#
# --- Getting League Team Stats for USHL 2005-2006 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
#
# --- Getting League Team Stats for USHL 2006-2007 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for ohio-junior-blue-jackets 9667 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
#
# --- Getting League Team Stats for USHL 2007-2008 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for ohio-junior-blue-jackets 9667 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
#
# --- Getting League Team Stats for USHL 2008-2009 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
#
# --- Getting League Team Stats for USHL 2009-2010 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for usntdp-juniors 5156 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
# --- Getting Team Player Stats for youngstown-phantoms 2628 ---
#
# --- Getting League Team Stats for USHL 2010-2011 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for dubuque-fighting-saints 1158 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for muskegon-lumberjacks 535 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for usntdp-juniors 5156 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
# --- Getting Team Player Stats for youngstown-phantoms 2628 ---
#
# --- Getting League Team Stats for USHL 2011-2012 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for dubuque-fighting-saints 1158 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for muskegon-lumberjacks 535 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for usntdp-juniors 5156 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
# --- Getting Team Player Stats for youngstown-phantoms 2628 ---
#
# --- Getting League Team Stats for USHL 2012-2013 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for dubuque-fighting-saints 1158 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for muskegon-lumberjacks 535 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for usntdp-juniors 5156 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
# --- Getting Team Player Stats for youngstown-phantoms 2628 ---
# --- Getting League Team Stats for USHL 2013-2014 ---
#
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for dubuque-fighting-saints 1158 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for indiana-ice 2167 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for muskegon-lumberjacks 535 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for usntdp-juniors 5156 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
# --- Getting Team Player Stats for youngstown-phantoms 2628 ---
#
# --- Getting League Team Stats for USHL 2014-2015 ---
#
# --- Getting Team Player Stats for bloomington-thunder 17113 ---
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# --- Getting Team Player Stats for chicago-steel 898 ---
# --- Getting Team Player Stats for des-moines-buccaneers 900 ---
# --- Getting Team Player Stats for dubuque-fighting-saints 1158 ---
# --- Getting Team Player Stats for fargo-force 1186 ---
# --- Getting Team Player Stats for green-bay-gamblers 901 ---
# --- Getting Team Player Stats for lincoln-stars 844 ---
# --- Getting Team Player Stats for madison-capitols 15749 ---
# --- Getting Team Player Stats for muskegon-lumberjacks 535 ---
# --- Getting Team Player Stats for omaha-lancers 954 ---
# --- Getting Team Player Stats for sioux-city-musketeers 903 ---
# --- Getting Team Player Stats for sioux-falls-stampede 904 ---
# --- Getting Team Player Stats for tri-city-storm 2710 ---
# --- Getting Team Player Stats for usntdp-juniors 5156 ---
# --- Getting Team Player Stats for waterloo-black-hawks 907 ---
# --- Getting Team Player Stats for youngstown-phantoms 2628 ---
#
# --- Getting League Team Stats for USHL 2015-2016 ---
#
# --- Getting Team Player Stats for bloomington-thunder 17113 ---
# --- Getting Team Player Stats for cedar-rapids-roughriders 783 ---
# ...
# --- Retrieving player info for: elijah-carels
# --- Retrieving player info for: ethan-eang
# --- ethan-eang bad player data ---
# --- Retrieving player info for: aidan-woodley
# --- Retrieving player info for: wayde-johannesson
# --- Retrieving player info for: jake-tremblay
# --- Retrieving player info for: carter-sawatzky
# --- Retrieving player info for: jeremy-bisson
# --- Retrieving player info for: jordan-simoneau
# --- Retrieving player info for: gage-misskey
# --- Retrieving player info for: austin-mikesch
# --- Retrieving player info for: zach-cox
# --- Retrieving player info for: caleb-paisley
# --- Retrieving player info for: tristan-petrie
# --- Retrieving player info for: adam-beckman
# --- Retrieving player info for: kalen-ukrainetz
# --- Retrieving player info for: dylan-kent
# --- Retrieving player info for: davis-chorney
# --- Retrieving player info for: luke-penner
# --- Retrieving player info for: brodie-girod
# --- Retrieving player info for: danton-l-heureux
# --- Retrieving player info for: jayden-bexte
# --- Retrieving player info for: dallen-erickson
# --- Retrieving player info for: olivier-lantagne
# --- Retrieving player info for: alexandre-desgagnes
# --- Retrieving player info for: max-salpeter
# --- Retrieving player info for: christopher-bernard
# --- Retrieving player info for: kurri-woodford
# --- Retrieving player info for: noah-bankowski
# --- Retrieving player info for: sam-robinson
# --- Retrieving player info for: keigan-callander
# --- Retrieving player info for: hardy-wagner
# --- Retrieving player info for: dylan-jones
# --- Retrieving player info for: quinn-schmiemann
# --- Retrieving player info for: cody-lehner
# --- Retrieving player info for: cade-kowalski
# --- Retrieving player info for: jordan-kazymyra
# --- Retrieving player info for: jessie-young
# --- Retrieving player info for: connor-pyne
# --- Retrieving player info for: garrett-szeremley
# --- Retrieving player info for: william-cruise
# --- Retrieving player info for: matthew-jones
# --- Retrieving player info for: calder-newson
# --- Retrieving player info for: connor-gabruch
# --- Retrieving player info for: zac-robins
# --- Retrieving player info for: riley-little
# --- Retrieving player info for: braden-birnie
# --- Retrieving player info for: mkyllan-couture
# --- Retrieving player info for: brendan-kemp
# --- Retrieving player info for: jarvis-gelowitz
# --- Retrieving player info for: austin-cook
# --- Retrieving player info for: cody-bruchkowski
# --- Retrieving player info for: slater-strong
# --- Retrieving player info for: william-brochu
# --- Retrieving player info for: charlie-risk
# --- Retrieving player info for: aiden-bulych
# --- Retrieving player info for: evan-nicholas
# --- Retrieving player info for: jarid-morhart
# --- Retrieving player info for: dalton-ossman
# --- Retrieving player info for: liam-hovland
# --- Retrieving player info for: carter-lake
# --- Retrieving player info for: jason-wenzel
# --- Retrieving player info for: keanan-sperling
# --- Retrieving player info for: mackenzie-walkington
# --- Retrieving player info for: austin-becker
# --- Retrieving player info for: brett-gammer
# --- Retrieving player info for: quintin-loon-stewardson
# --- Retrieving player info for: regan-doig
# --- Retrieving player info for: tanner-scott
# --- Retrieving player info for: garrett-johnson
# --- Retrieving player info for: ryan-granville
# --- Retrieving player info for: seth-summers
# --- Retrieving player info for: tanner-robin
# --- Retrieving player info for: jacob-bayne
# --- Retrieving player info for: adam-weiner
# --- Retrieving player info for: shaye-sommerfeld
# --- Retrieving player info for: steven-kesslering
# --- Retrieving player info for: adam-kydd
# --- Retrieving player info for: luke-fennig
# --- Retrieving player info for: mitchell-bosch
# --- Retrieving player info for: bryce-platt
# --- Retrieving player info for: will-koop
# --- Retrieving player info for: isaiah-thomas
# --- Retrieving player info for: tristyn-deroose
# --- Retrieving player info for: eddie-gallagher
# --- Retrieving player info for: devan-harrison
# --- Retrieving player info for: kolton-leslie
# --- Retrieving player info for: george-cathers
# --- Retrieving player info for: bronson-adams
# --- Retrieving player info for: cody-davis
# --- Retrieving player info for: cal-caragata
# --- Retrieving player info for: billy-klymchuk
# --- Retrieving player info for: alec-cokley
# --- Retrieving player info for: tyler-higgins
# --- Retrieving player info for: ryder-richmond
# --- Retrieving player info for: reid-robertson
# --- Retrieving player info for: shayde-peterson
# --- Retrieving player info for: hendrik-de-klerk
# --- Retrieving player info for: leyson-coleman
# --- Retrieving player info for: jacob-schnapp
# --- Retrieving player info for: parker-hendren
# --- Retrieving player info for: owen-guenter
# --- Retrieving player info for: chase-felgueiras
# --- Retrieving player info for: luke-spadafora
# --- Retrieving player info for: reid-arnold
# --- Retrieving player info for: riker-franczak
# --- Retrieving player info for: daunte-fortner
# --- Retrieving player info for: colin-macpherson
# --- Retrieving player info for: jackson-kobelka
# --- Retrieving player info for: max-johnson
# --- Retrieving player info for: chase-lacombe
# --- Retrieving player info for: luke-lonneman
# --- Retrieving player info for: liam-drager
# --- Retrieving player info for: jaxon-penner
# --- Retrieving player info for: james-form
# --- Retrieving player info for: mitch-babbik
# --- Retrieving player info for: ty-enns
# --- Retrieving player info for: caden-benson
# --- Retrieving player info for: clay-keeley
# --- Retrieving player info for: nate-keeley
# --- Retrieving player info for: steven-avalone
# --- Retrieving player info for: liam-fraser
# --- Retrieving player info for: tyson-laduke
# --- Retrieving player info for: grant-ziegler
# --- Retrieving player info for: mac-gross
# --- Retrieving player info for: troy-kosmynka
# --- Retrieving player info for: jake-koroluk
# --- Retrieving player info for: matthew-dyck
# --- Retrieving player info for: jake-gudjonson
# --- Retrieving player info for: stewart-pond
# --- Retrieving player info for: flynn-perry
# --- Retrieving player info for: max-kleiner
# --- Retrieving player info for: samson-mouland
# --- Retrieving player info for: joshua-poon
# --- joshua-poon bad player data ---
# --- Retrieving player info for: grant-longtin
# --- Retrieving player info for: jake-chartier
# --- Retrieving player info for: macrae-setoguchi
# --- Retrieving player info for: peyton-malcolm
# --- Retrieving player info for: antoine-dumoulin
# --- Retrieving player info for: brandt-fiske
# --- Retrieving player info for: tyler-johnson
# --- Retrieving player info for: logan-holm
# --- Retrieving player info for: bailey-hartman
# --- Retrieving player info for: skylar-olson
# --- Retrieving player info for: quinn-strang
# --- Retrieving player info for: josh-peppler
# --- Retrieving player info for: nico-hemming
# --- Retrieving player info for: alex-rondeau
# --- Retrieving player info for: chase-anderson
# --- Retrieving player info for: gabe-odowichuk
# --- Retrieving player info for: braeden-young
# --- Retrieving player info for: tulsen-fawcett
# --- Retrieving player info for: brendan-adams
# --- Retrieving player info for: dylan-ashe
# --- Retrieving player info for: ethan-neufeld
# --- Retrieving player info for: lucas-ochitwa
# --- Retrieving player info for: ty-albrecht
# --- Retrieving player info for: thomas-mcguire
# --- Retrieving player info for: aidan-mcnabb
# --- Retrieving player info for: luke-nkwama
# --- Retrieving player info for: max-mcpeak
# --- Retrieving player info for: sam-mudd
# --- Retrieving player info for: john-elliott
# --- Retrieving player info for: jaxon-tait
# --- Retrieving player info for: ryan-heino
# --- Retrieving player info for: nash-wood
# --- Retrieving player info for: ethan-schmor
# --- Retrieving player info for: malik-kaddoura
# --- Retrieving player info for: michael-boutoussov
# --- Retrieving player info for: mason-mcintosh
# --- Retrieving player info for: wyatt-wong
# --- Retrieving player info for: arik-breton
# --- Retrieving player info for: carson-erhardt
# --- Retrieving player info for: jaxsen-wiebe
# --- Retrieving player info for: michael-makarenko
# --- Retrieving player info for: jack-lenchyshyn
# --- Retrieving player info for: walker-cote
# --- Retrieving player info for: josh-lester
# --- Retrieving player info for: colton-nikiforuk
# --- Retrieving player info for: eric-sorensen
# --- Retrieving player info for: andrew-smiley
# --- Retrieving player info for: mackenzie-macdonald
# --- Retrieving player info for: logan-moon
# --- Retrieving player info for: zak-yewchuk
# --- Retrieving player info for: cole-beamin
# --- Retrieving player info for: caleb-grandfield
# --- Retrieving player info for: jacob-schuldt
# --- Retrieving player info for: ethan-bulitzudell
# --- ethan-bulitzudell bad player data ---
# --- Retrieving player info for: luke-mcfarlane
# --- Retrieving player info for: jakob-breault
# --- Retrieving player info for: jarrett-penner
# --- Retrieving player info for: charles-martin
# --- Retrieving player info for: kyle-robinson
# --- Retrieving player info for: sho-takai
# --- Retrieving player info for: cole-stevenson
# --- Retrieving player info for: tanner-tarbell
# --- Retrieving player info for: cole-golden
# --- Retrieving player info for: qaritaq-clark
# --- Retrieving player info for: joseph-santalucia
# --- Retrieving player info for: keaton-sorensen
# --- Retrieving player info for: jake-dale
# --- Retrieving player info for: matt-valure
# --- Retrieving player info for: alex-liskowich
# --- Retrieving player info for: carter-belitski
# --- Retrieving player info for: rhett-stevenson
# --- Retrieving player info for: drew-anderson
# --- Retrieving player info for: jacob-piller
# --- Retrieving player info for: rhett-frey
# --- rhett-frey bad player data ---
# --- Retrieving player info for: tyler-leibl
# --- Retrieving player info for: bryce-krauter
# --- Retrieving player info for: khale-skinner
# --- Retrieving player info for: sven-schefer
# --- Retrieving player info for: cole-dekoninck
# --- Retrieving player info for: luke-arndt
# --- Retrieving player info for: teagan-koehler
# --- Retrieving player info for: quade-froese
# --- Retrieving player info for: liam-rutten
# --- Retrieving player info for: todd-johnson
# --- Retrieving player info for: kishaun-gervais
# --- Retrieving player info for: tyson-janzen
# --- Retrieving player info for: ryan-ries
# --- Retrieving player info for: jaxon-blight
# --- Retrieving player info for: greg-mulhall
# --- Retrieving player info for: jordan-mis
# --- Retrieving player info for: evan-sare
# --- Retrieving player info for: vaughn-wilgosh
# --- Retrieving player info for: connor-giebel
# --- Retrieving player info for: jordan-repsch
# --- Retrieving player info for: carson-reagan
# --- Retrieving player info for: dace-prymak
# --- Retrieving player info for: liam-antoniuk
# --- Retrieving player info for: hunter-rambow
# --- Retrieving player info for: hunter-partsch
# --- Retrieving player info for: holden-doell
# --- Retrieving player info for: walter-somers
# --- Retrieving player info for: caelan-fitzpatrick
# --- Retrieving player info for: jordan-gagnon
# --- Retrieving player info for: riley-girod
# --- Retrieving player info for: hunter-weber
# --- Retrieving player info for: kai-joorisity
# --- Retrieving player info for: jake-southgate
# --- Retrieving player info for: palmer-sinclair
# --- palmer-sinclair bad player data ---
# --- Retrieving player info for: griffin-asham-moroz
# --- Retrieving player info for: tyler-savage
# --- Retrieving player info for: brady-nicholas
# --- Retrieving player info for: troy-hamilton
# --- Retrieving player info for: kersey-reich
# --- Retrieving player info for: dayton-deics
# --- Retrieving player info for: dain-sardelli
# --- Retrieving player info for: erik-boers
# --- Retrieving player info for: caleb-petrie
# --- Retrieving player info for: mason-strutt
# --- Retrieving player info for: matt-millette
# --- Retrieving player info for: max-wanner
# --- Retrieving player info for: cole-rafuse
# --- Retrieving player info for: alec-malo
# --- Retrieving player info for: tristan-lemyre
# --- Retrieving player info for: chase-haygarth
# --- Retrieving player info for: easton-haygarth
# --- Retrieving player info for: dane-hirst
# --- Retrieving player info for: brandon-cianflone
# --- Retrieving player info for: jaeden-mercier
# --- Retrieving player info for: adam-victorino
# --- Retrieving player info for: hayden-clayton
# --- Retrieving player info for: matt-raymond
# --- Retrieving player info for: cole-vardy
# --- Retrieving player info for: mason-kaspick
# --- Retrieving player info for: jack-craycroft
# --- Retrieving player info for: noah-kuntz
# --- Retrieving player info for: mackenzie-carson
# --- Retrieving player info for: cole-duperreault
# --- Retrieving player info for: ashton-ferster
# --- Retrieving player info for: hunter-larocque
# --- Retrieving player info for: jonah-henderson
# --- Retrieving player info for: marek-schneider
# --- Retrieving player info for: drayson-collyer
# --- Retrieving player info for: karter-mcnarland
# --- Retrieving player info for: braiden-koran
# --- Retrieving player info for: justin-jamer
# --- Retrieving player info for: spencer-mchardy
# --- Retrieving player info for: josh-paulhus
# --- Retrieving player info for: nicksha-eric
# --- Retrieving player info for: noah-barlage
# --- Retrieving player info for: spencer-weinkauf
# --- Retrieving player info for: isaac-leik
# --- Retrieving player info for: connor-nolan
# --- Retrieving player info for: jared-shuter
# --- Retrieving player info for: zach-whittaker
# --- Retrieving player info for: ayden-third
# --- Retrieving player info for: bradley-stieduhar
# --- Retrieving player info for: ben-wourms-rowe
# --- Retrieving player info for: scott-mckenzie
# --- Retrieving player info for: ethan-king
# --- Retrieving player info for: noah-lindsay
# --- Retrieving player info for: ethan-mack
# --- Retrieving player info for: michael-neumeier
# --- Retrieving player info for: sam-witt
# --- Retrieving player info for: jake-huska
# --- Retrieving player info for: mark-snarr
# --- Retrieving player info for: logan-linklater
# --- Retrieving player info for: levi-young
# --- Retrieving player info for: ethan-grabowski
# --- Retrieving player info for: connor-tyhy
# --- Retrieving player info for: dylan-wenzel
# --- Retrieving player info for: colby-brett
# --- Retrieving player info for: kai-studler
# --- Retrieving player info for: daylon-mannon
# --- Retrieving player info for: kyle-ford
# --- Retrieving player info for: spencer-kennedy
# --- Retrieving player info for: aaron-greyeyes
# --- Retrieving player info for: chad-mcilwain
# --- Retrieving player info for: rowan-barnes
# --- Retrieving player info for: ty-budai
# --- Retrieving player info for: kalem-hanlon
# --- Retrieving player info for: kaiden-collumb
# --- Retrieving player info for: nolan-spadafore
# --- Retrieving player info for: aidan-morrison
# --- Retrieving player info for: grady-birk
# --- Retrieving player info for: alex-ozar
# --- Retrieving player info for: sebastien-archambault
# --- Retrieving player info for: nakoda-thunderchief
# --- nakoda-thunderchief bad player data ---
# --- Retrieving player info for: bryce-trimmer
# --- Retrieving player info for: cobe-delaney
# --- Retrieving player info for: ben-tkachuk
# --- ben-tkachuk bad player data ---
# --- Retrieving player info for: marco-lopez
# --- Retrieving player info for: christian-albertson
# --- Retrieving player info for: seth-mcculloch
# --- Retrieving player info for: ben-chase
# --- Retrieving player info for: greg-parker
# --- Retrieving player info for: luc-marleau
# --- Retrieving player info for: deklan-whillans
# --- Retrieving player info for: vaclav-prospal
# --- Retrieving player info for: brady-clayton
# --- Retrieving player info for: ryan-maclean
# --- Retrieving player info for: alaister-standen
# --- Retrieving player info for: logen-hammett
# --- Retrieving player info for: nicolas-porterfield
# --- Retrieving player info for: jake-spak
# --- Retrieving player info for: dylan-wells
# --- Retrieving player info for: blake-campbell
# --- Retrieving player info for: braden-larochelle
# --- Retrieving player info for: tanner-brown
# --- Retrieving player info for: jaden-hewes

# %% [markdown]
# ### Adding Player Info that's missing due to IP lock

# %%
# load database credentials and create connection
user, password, server, database, port = load_db_credentials()
engine = create_engine(f'postgresql://{user}:{password}@{server}:{port}/{database}')

all_skaters = pd.read_sql(''' select distinct playerid, shortname from skater_stats ''', engine)
all_goalies = pd.read_sql(''' select distinct playerid, shortname from goalie_stats ''', engine)
info = pd.read_sql(''' select distinct playerid, shortname from player_info ''', engine)

all_players = pd.concat([all_skaters,
                         all_goalies], sort=False)

players = all_players[all_players.playerid.isin(list(set(all_players.playerid) - set(info.playerid)))]

# %%
player_info = []

for playerid, shortname in zip(players.playerid, players.shortname):
    try:
        player = get_player_info(playerid, shortname)
        player_info.append(player)
    except:
        print(f'--- {shortname} bad player data ---')
        continue

player_info = pd.concat(player_info, sort=False)
# gets draft eligibility for all players
player_info = get_draft_eligibility(player_info)
# Out:
# --- Retrieving player info for: josh-chase
# --- Retrieving player info for: jesse-hudkins
# --- Retrieving player info for: otto-mild
# --- Retrieving player info for: graham-watson
# --- Retrieving player info for: logan-gorsalitz
# --- Retrieving player info for: barnabas-birkeland
# --- Retrieving player info for: ryan-chynoweth
# --- Retrieving player info for: peter-stratis
# --- Retrieving player info for: martin-curda
# --- Retrieving player info for: miroslav-juda
# --- Retrieving player info for: jaroslav-flieger
# --- Retrieving player info for: darren-nesbitt
# --- Retrieving player info for: gleb-bobin
# --- Retrieving player info for: matthew-whittaker
# --- Retrieving player info for: christopher-blair
# --- Retrieving player info for: igor-safaraleyev
# --- Retrieving player info for: ashton-casault
# --- Retrieving player info for: alexander-kadeykin
# --- Retrieving player info for: eddie-ahlmark
# --- Retrieving player info for: oleg-nazarov
# --- Retrieving player info for: toni-lehikoinen
# --- Retrieving player info for: brett-munroe
# --- Retrieving player info for: ivan-kravchenko
# --- Retrieving player info for: michael-snowie
# --- Retrieving player info for: jiri-valjakka
# --- Retrieving player info for: john-aonso
# --- Retrieving player info for: oliver-smith
# --- Retrieving player info for: zachary-byard
# --- Retrieving player info for: ilya-pugin
# --- Retrieving player info for: eero-klintrup
# --- Retrieving player info for: radek-meidl
# --- Retrieving player info for: spencer-roberts
# --- Retrieving player info for: robert-von-gerdten
# --- Retrieving player info for: jan-koktan
# --- Retrieving player info for: anthony-paveglio
# --- Retrieving player info for: riley-scott
# --- Retrieving player info for: ryan-mast
# --- Retrieving player info for: eli-pilosof
# --- Retrieving player info for: mikhail-kalinin
# --- Retrieving player info for: james-gibson
# --- Retrieving player info for: tomas-voracek
# --- Retrieving player info for: sam-plaquin
# --- Retrieving player info for: fyodor-averyushkin
# --- Retrieving player info for: miska-alakoski
# --- Retrieving player info for: maksud-valeyev
# --- Retrieving player info for: ayrton-martino
# --- Retrieving player info for: yevgeni-shinkaretsky
# --- Retrieving player info for: lukas-rousek
# --- Retrieving player info for: josh-ruys
# --- Retrieving player info for: spencer-bell
# --- spencer-bell bad player data ---
# --- Retrieving player info for: ivar-kjellsson
# --- Retrieving player info for: justin-cormier
# --- Retrieving player info for: jake-hill
# --- jake-hill bad player data ---
# --- Retrieving player info for: michal-hlinka
# --- Retrieving player info for: john-holmstedt
# --- Retrieving player info for: jan-trojan
# --- Retrieving player info for: paycen-bjorklund
# --- Retrieving player info for: brodie-welsh
# --- Retrieving player info for: viktor-ekk
# --- Retrieving player info for: brent-clarke
# --- Retrieving player info for: maxim-romanov
# --- Retrieving player info for: eduard-smirnov
# --- Retrieving player info for: aku-palsola
# --- Retrieving player info for: tyler-kelly
# --- Retrieving player info for: janne-jaakola
# --- Retrieving player info for: riku-rahikainen
# --- Retrieving player info for: bogdan-zhilyakov
# --- Retrieving player info for: eero-jaaskelainen
# --- Retrieving player info for: taylor-raszka
# --- Retrieving player info for: jackson-alexeev
# --- Retrieving player info for: nathael-roy
# --- Retrieving player info for: martin-makinen
# --- Retrieving player info for: kamil-shiafotdinov
# --- Retrieving player info for: ilya-gaidamaka
# --- Retrieving player info for: mikhail-yuzeyev
# --- Retrieving player info for: valdemar-jirus
# --- Retrieving player info for: teemu-kulosaari
# --- Retrieving player info for: alexander-dudin
# --- Retrieving player info for: romano-morrison
# --- Retrieving player info for: olivier-nadeau
# --- Retrieving player info for: yegor-konstantinov
# --- Retrieving player info for: josef-klepetko
# --- Retrieving player info for: mikael-bjerdahl
# --- Retrieving player info for: lucas-vidinha
# --- Retrieving player info for: jean-francois-grenier
# --- Retrieving player info for: valtteri-vuorenmaa
# --- Retrieving player info for: georgi-larshin
# --- Retrieving player info for: jake-gaudet
# --- Retrieving player info for: sergei-konkov
# --- Retrieving player info for: keith-wynn
# --- Retrieving player info for: alexander-yevchuk
# --- Retrieving player info for: alexander-osipenko
# --- Retrieving player info for: alexander-nikitin
# --- Retrieving player info for: mikhail-konkov
# --- Retrieving player info for: roman-vasilyev
# --- Retrieving player info for: justus-nurmi
# --- Retrieving player info for: tomas-preucil
# --- Retrieving player info for: lukas-spelda
# --- Retrieving player info for: brayden-beckley
# --- Retrieving player info for: robert-mokry
# --- Retrieving player info for: andrew-radjenovic
# --- Retrieving player info for: maxim-abayev
# --- Retrieving player info for: maxim-polevshchikov
# --- Retrieving player info for: konsta-jaakola
# --- Retrieving player info for: jarrett-robertson
# --- Retrieving player info for: yevgeni-shmagin
# --- Retrieving player info for: adam-szwed
# --- Retrieving player info for: dustin-dubas
# --- dustin-dubas bad player data ---
# --- Retrieving player info for: rasmus-laine
# --- Retrieving player info for: alex-jaeckle
# --- Retrieving player info for: henrik-suikkanen
# --- Retrieving player info for: marcus-wiebe
# --- Retrieving player info for: markus-saarinen
# --- Retrieving player info for: anthony-aguanno
# --- Retrieving player info for: kalle-kortteinen
# --- Retrieving player info for: martin-vsetecka
# --- Retrieving player info for: joel-ray
# --- Retrieving player info for: paul-lee
# --- Retrieving player info for: lukas-netolicky
# --- Retrieving player info for: petr-mika
# --- Retrieving player info for: arkadi-axyonov
# --- Retrieving player info for: matt-lombardi
# --- Retrieving player info for: alexander-glazkov
# --- Retrieving player info for: eric-delong
# --- Retrieving player info for: ilkka-pekka-kiukas
# --- Retrieving player info for: dante-pavese
# --- dante-pavese bad player data ---
# --- Retrieving player info for: paul-mcfarland
# --- Retrieving player info for: david-zachar
# --- Retrieving player info for: alexei-nechkin
# --- Retrieving player info for: giovanni-vallati
# --- Retrieving player info for: liam-kerins
# --- Retrieving player info for: ilya-goncharov
# --- Retrieving player info for: pavel-medvedev
# --- Retrieving player info for: matt-mcnamara
# --- Retrieving player info for: paul-gallucci
# --- Retrieving player info for: jordan-george
# --- Retrieving player info for: sever-bilgili
# --- Retrieving player info for: reid-nemeth
# --- Retrieving player info for: zachary-martin
# --- Retrieving player info for: alexander-polukhin
# --- Retrieving player info for: daniel-robertson
# --- Retrieving player info for: jaakko-heikkila
# --- Retrieving player info for: jakub-hlusicka
# --- Retrieving player info for: joshua-dressler
# --- Retrieving player info for: alexandre-lacombe
# --- Retrieving player info for: kolton-dixon
# --- Retrieving player info for: markus-piispanen
# --- Retrieving player info for: petr-seidler
# --- Retrieving player info for: james-lister
# --- Retrieving player info for: nicholas-romano
# --- Retrieving player info for: valtteri-niemi
# --- Retrieving player info for: jan-cesnek
# --- Retrieving player info for: ji-min-kim
# --- Retrieving player info for: camden-zappi
# --- camden-zappi bad player data ---
# --- Retrieving player info for: justin-crawford
# --- Retrieving player info for: sean-toriumi
# --- sean-toriumi bad player data ---
# --- Retrieving player info for: scott-lavigne
# --- Retrieving player info for: yevgeni-fomichyov
# --- Retrieving player info for: brennan-volcan
# --- Retrieving player info for: graeme-maclean
# --- Retrieving player info for: kevin-cooper
# --- Retrieving player info for: francis-landers
# --- Retrieving player info for: alexander-saranchuk
# --- Retrieving player info for: jacob-bauchman
# --- Retrieving player info for: scott-pungor
# --- Retrieving player info for: sammy-banga
# --- Retrieving player info for: joakim-englund
# --- Retrieving player info for: sergei-smurov
# --- Retrieving player info for: ryan-dau
# --- Retrieving player info for: owen-mcgowan
# --- Retrieving player info for: michael-nairn
# --- Retrieving player info for: campbell-pickard
# --- Retrieving player info for: grigori-ponkratov
# --- Retrieving player info for: corey-ronan
# --- Retrieving player info for: yevgeni-vilensky
# --- Retrieving player info for: rasmus-hemstrom
# --- Retrieving player info for: matti-pinomaki
# --- Retrieving player info for: mike-wills
# --- Retrieving player info for: pavel-kim
# --- Retrieving player info for: jegors-mateiko
# --- Retrieving player info for: danil-makarov
# --- Retrieving player info for: alvari-rautiainen
# --- Retrieving player info for: tommy-tanner
# --- Retrieving player info for: warren-steele
# --- Retrieving player info for: michal-skoumal
# --- Retrieving player info for: nolan-descoteaux
# --- Retrieving player info for: david-blazek
# --- Retrieving player info for: radek-slama
# --- Retrieving player info for: andrei-galushkin
# --- Retrieving player info for: niko-snellman
# --- Retrieving player info for: lauri-viitanen
# --- Retrieving player info for: matt-hedrick
# --- Retrieving player info for: arslan-akhmetyanov
# --- Retrieving player info for: jyri-waajakoski
# --- Retrieving player info for: t.j.-smith
# --- Retrieving player info for: olivier-daunais
# --- Retrieving player info for: juuso-tani
# --- Retrieving player info for: roope-markula
# --- Retrieving player info for: jonah-coonishish
# --- Retrieving player info for: janne-toivanen
# --- Retrieving player info for: coleton-cianci
# --- Retrieving player info for: maxim-girin
# --- Retrieving player info for: valtteri-salmelainen
# --- Retrieving player info for: mitchell-robillard
# --- Retrieving player info for: matthew-muzyka
# --- Retrieving player info for: hunter-garlasco
# --- Retrieving player info for: dmitri-sarazov
# --- Retrieving player info for: tyler-campbell
# --- Retrieving player info for: axel-rioux
# --- Retrieving player info for: scott-collins
# --- Retrieving player info for: lauri-seppa
# --- Retrieving player info for: michal-vondrka
# --- Retrieving player info for: denis-mashanov
# --- Retrieving player info for: andrei-korshunov
# --- Retrieving player info for: evan-pringle
# --- Retrieving player info for: miles-winter
# --- Retrieving player info for: alex-whelan
# --- Retrieving player info for: andreas-falk
# --- Retrieving player info for: jean-francois-leblanc
# --- Retrieving player info for: mikko-honkanen
# --- Retrieving player info for: remy-parker
# --- Retrieving player info for: gleb-panfilov
# --- Retrieving player info for: erik-norback
# --- Retrieving player info for: cody-hendsbee
# --- Retrieving player info for: sergei-malyavko
# --- Retrieving player info for: kirils-mitrofanovs
# --- Retrieving player info for: andrew-mcintyre
# --- Retrieving player info for: peter-starrett
# --- Retrieving player info for: yaroslav-chupris
# --- Retrieving player info for: ryan-klinck
# --- Retrieving player info for: dylan-thiessen
# --- Retrieving player info for: david-sestak
# --- Retrieving player info for: william-stromgren
# --- Retrieving player info for: rasmus-klarck
# --- Retrieving player info for: a.j.-van-doorn
# --- Retrieving player info for: simon-masek
# --- Retrieving player info for: john-kelly
# --- Retrieving player info for: dylan-robinson
# --- Retrieving player info for: alexandre-couture
# --- Retrieving player info for: jean-michel-bolduc
# --- Retrieving player info for: trevor-abbott
# --- Retrieving player info for: jakin-smallwood
# --- Retrieving player info for: vaclav-pletka
# --- Retrieving player info for: andrew-glass
# --- Retrieving player info for: tom-biondich
# --- Retrieving player info for: joonas-pakkanen
# --- Retrieving player info for: matti-tiilikainen
# --- Retrieving player info for: jan-dresler
# --- Retrieving player info for: steve-kovalchik
# --- Retrieving player info for: mat-knoll
# --- Retrieving player info for: alexei-morozov
# --- Retrieving player info for: thomas-lang
# --- Retrieving player info for: francis-lambert-lemay
# --- Retrieving player info for: yevgeni-bumagin
# --- Retrieving player info for: darcy-ashley
# --- Retrieving player info for: richard-beauchamp
# --- Retrieving player info for: alexei-tkachuk
# --- Retrieving player info for: brayden-mcdonald
# --- Retrieving player info for: corbin-bean
# --- Retrieving player info for: daniel-mele
# --- Retrieving player info for: johnny-ulicny
# --- Retrieving player info for: rob-ringuette
# --- Retrieving player info for: luke-burghardt
# --- Retrieving player info for: tom-collingham
# --- Retrieving player info for: scott-oke
# --- Retrieving player info for: niko-jarvinen
# --- Retrieving player info for: martin-hamrlik
# --- Retrieving player info for: matt-rokosh
# --- Retrieving player info for: matt-prinsen
# --- Retrieving player info for: eetu-sopanen
# --- Retrieving player info for: gary-friesen
# --- Retrieving player info for: zach-hepler
# --- Retrieving player info for: owen-burnell
# --- Retrieving player info for: ivan-yemets
# --- Retrieving player info for: brock-becker
# --- Retrieving player info for: yegor-zubov
# --- Retrieving player info for: patrik-ruiz
# --- Retrieving player info for: alexander-yasavin
# --- Retrieving player info for: alexander-renyov
# --- Retrieving player info for: mason-mantzavrakos
# --- Retrieving player info for: ethan-burroughs
# --- Retrieving player info for: calle-steen
# --- Retrieving player info for: weston-tardy
# --- Retrieving player info for: sami-laihanen
# --- Retrieving player info for: joey-ferriss
# --- Retrieving player info for: connor-currie
# --- Retrieving player info for: james-unger
# --- Retrieving player info for: patrick-stillar
# --- Retrieving player info for: denis-kokarev
# --- Retrieving player info for: jeason-lecours
# --- Retrieving player info for: artur-gilyazeyev
# --- Retrieving player info for: zack-dorval
# --- Retrieving player info for: radoslav-kropac
# --- Retrieving player info for: doug-reid
# --- Retrieving player info for: jacob-jammes
# --- Retrieving player info for: david-vsetecka
# --- Retrieving player info for: andrew-standish
# --- Retrieving player info for: ruslan-iskhakov
# --- Retrieving player info for: andrei-pichukha
# --- Retrieving player info for: joachim-vachon
# --- Retrieving player info for: anton-pervov
# --- Retrieving player info for: mark-smith
# --- Retrieving player info for: charles-milette
# --- Retrieving player info for: jean-philippe-mathieu
# --- Retrieving player info for: lukas-doudera
# --- Retrieving player info for: charlie-da-fonseca
# --- Retrieving player info for: maxim-sindimirov
# --- Retrieving player info for: colin-macdonald
# --- Retrieving player info for: j.p.-martignetti
# --- Retrieving player info for: jackson-hay
# --- Retrieving player info for: will-vosejpka
# --- Retrieving player info for: samuli-hoskonen
# --- Retrieving player info for: charles-corriveau
# --- Retrieving player info for: rodion-tsizman
# --- Retrieving player info for: adam-oates
# --- Retrieving player info for: jonathan-laberge
# --- Retrieving player info for: kirill-smirnov
# --- Retrieving player info for: erik-furmark
# --- Retrieving player info for: james-bodanis
# --- james-bodanis bad player data ---
# --- Retrieving player info for: karel-rosa
# --- Retrieving player info for: jeremy-sheppard
# --- Retrieving player info for: ivan-kupchenko
# --- Retrieving player info for: vaclav-nemec
# --- Retrieving player info for: rafael-batyrshin
# --- Retrieving player info for: antoine-quevillon
# --- Retrieving player info for: mike-fournier
# --- Retrieving player info for: patrik-lusnak
# --- Retrieving player info for: mark-smirnov
# --- Retrieving player info for: tyler-shippel
# --- Retrieving player info for: brook-hiddink
# --- Retrieving player info for: jack-luca
# --- Retrieving player info for: alexander-popkov
# --- Retrieving player info for: eero-kiiski
# --- Retrieving player info for: mikhail-abramov
# --- Retrieving player info for: jamie-parker
# --- Retrieving player info for: pavel-teterin
# --- Retrieving player info for: vasili-danilov
# --- Retrieving player info for: francis-leblanc
# --- Retrieving player info for: nick-boyagian
# --- Retrieving player info for: david-muratov
# --- Retrieving player info for: jan-marousek
# --- Retrieving player info for: yevgeni-ostrovsky
# --- Retrieving player info for: ethan-stewart
# --- Retrieving player info for: artyom-senkevich
# --- Retrieving player info for: ryan-smith
# --- Retrieving player info for: conor-carson
# --- Retrieving player info for: brian-ihnacak
# --- Retrieving player info for: oscar-johansen
# --- Retrieving player info for: oleg-korchagin
# --- Retrieving player info for: francis-thibeault
# --- Retrieving player info for: igor-bondyrev
# --- Retrieving player info for: joonas-jalvanti
# --- Retrieving player info for: james-doering
# --- Retrieving player info for: ruslan-sadretdinov
# --- Retrieving player info for: vladislav-tsurikov
# --- Retrieving player info for: eero-hyvarinen
# --- Retrieving player info for: jeremy-gottzmann
# --- Retrieving player info for: jonathan-hill
# --- Retrieving player info for: stefan-lassen
# --- Retrieving player info for: vincent-bernier
# --- Retrieving player info for: lorne-tessier
# --- Retrieving player info for: juuso-nieminen
# --- Retrieving player info for: peter-tiivola
# --- Retrieving player info for: tim-fallowfield
# --- Retrieving player info for: filip-dvorak
# --- Retrieving player info for: artyom-gladkov
# --- Retrieving player info for: zack-di-cesare
# --- Retrieving player info for: brennan-menard
# --- Retrieving player info for: jason-goodship
# --- Retrieving player info for: adam-vylicil
# --- Retrieving player info for: antti-palojarvi
# --- Retrieving player info for: miroslav-durak
# --- Retrieving player info for: juraj-jurik
# --- Retrieving player info for: mattia-bortolotto
# --- Retrieving player info for: chad-denault
# --- Retrieving player info for: mike-campaner
# --- Retrieving player info for: charles-antoine-roy
# --- Retrieving player info for: arturs-sevcenko
# --- Retrieving player info for: ivan-kurov
# --- Retrieving player info for: tomi-kaitarinne
# --- Retrieving player info for: samuel-l-italien
# --- Retrieving player info for: kyle-hunter
# --- Retrieving player info for: oleg-lomako
# --- Retrieving player info for: jacob-squires
# --- Retrieving player info for: jan-kana
# --- Retrieving player info for: taige-harding
# --- Retrieving player info for: ondrej-vodsedalek
# --- Retrieving player info for: kaleb-denham
# --- Retrieving player info for: jordan-anderson
# --- Retrieving player info for: andrei-s.-alexeyev
# --- Retrieving player info for: eemil-viro
# --- Retrieving player info for: yegor-milovzorov
# --- Retrieving player info for: martin-wszolek
# --- Retrieving player info for: zach-szajner
# --- Retrieving player info for: albert-alikov
# --- Retrieving player info for: alexandre-vachon
# --- Retrieving player info for: victor-widlund
# --- Retrieving player info for: isak-lindgren
# --- Retrieving player info for: rock-regimbald
# --- Retrieving player info for: lem-randall
# --- Retrieving player info for: brian-kolb
# --- Retrieving player info for: jere-jokinen
# --- Retrieving player info for: patrick-klazer
# --- Retrieving player info for: alex-bradley
# --- Retrieving player info for: kirill-petkov
# --- Retrieving player info for: bill-terpstra
# --- Retrieving player info for: david-zdenek
# --- Retrieving player info for: marc-antoine-juneau
# --- Retrieving player info for: cole-svenson
# --- Retrieving player info for: alexei-akifyev
# --- Retrieving player info for: vincent-chapleau
# --- Retrieving player info for: michal-klima
# --- Retrieving player info for: nate-peterson
# --- Retrieving player info for: jiri-pilusa
# --- Retrieving player info for: mikael-kurki
# --- Retrieving player info for: ivan-kuznetsov
# --- Retrieving player info for: jiri-smejkal
# --- Retrieving player info for: tengiz-arslan
# --- Retrieving player info for: tanner-hildebrandt
# --- Retrieving player info for: brandon-tomines
# --- Retrieving player info for: yevgeni-rabadzhi
# --- Retrieving player info for: nikita-burmago
# --- Retrieving player info for: nikita-strizhov
# --- Retrieving player info for: ivan-huml
# --- Retrieving player info for: samppa-saarinen
# --- Retrieving player info for: filip-gunnarsson
# --- Retrieving player info for: alexander-figurin
# --- Retrieving player info for: henri-knaapi
# --- Retrieving player info for: juha-pekka-ryynanen
# --- Retrieving player info for: santeri-ovaska
# --- Retrieving player info for: chris-johnston
# --- Retrieving player info for: matti-aho
# --- Retrieving player info for: jeff-barletta
# --- Retrieving player info for: cory-tanaka
# --- Retrieving player info for: brandon-prophet
# --- Retrieving player info for: airat-badegyev
# --- Retrieving player info for: david-harris
# --- Retrieving player info for: lukas-pollock
# --- Retrieving player info for: roy-pihlstrom
# --- Retrieving player info for: pierre-luc-champagne
# --- Retrieving player info for: mikhail-v.-kozlov
# --- Retrieving player info for: brandon-maclean
# --- Retrieving player info for: doug-krantz
# --- Retrieving player info for: joseph-dumais
# --- Retrieving player info for: marcus-kichton
# --- Retrieving player info for: braydon-blight
# --- Retrieving player info for: colin-moore
# --- Retrieving player info for: jordan-thompson
# --- Retrieving player info for: ville-varmavuo
# --- Retrieving player info for: anton-straka
# --- Retrieving player info for: timi-lehti
# --- Retrieving player info for: stephen-cooney
# --- Retrieving player info for: brandon-sabatini
# --- Retrieving player info for: roger-videll
# --- Retrieving player info for: samuel-carrier
# --- Retrieving player info for: mitch-atkins
# --- Retrieving player info for: matti-kivisilta
# --- Retrieving player info for: roman-rac
# --- Retrieving player info for: radoslav-macik
# --- Retrieving player info for: juho-haikola
# --- Retrieving player info for: artyom-sevostyanov
# --- Retrieving player info for: matyas-filip
# --- Retrieving player info for: kyle-chartrand
# --- Retrieving player info for: brayden-krieger
# --- Retrieving player info for: christophe-jutras
# --- Retrieving player info for: anthony-di-cesare
# --- Retrieving player info for: evan-johnston
# --- Retrieving player info for: c.j.-stubbs
# --- Retrieving player info for: kenny-nelson
# --- Retrieving player info for: derek-mcleod
# --- Retrieving player info for: ethan-lazaro
# --- Retrieving player info for: vadim-sushko
# --- Retrieving player info for: daniel-d-amato
# --- Retrieving player info for: arttu-ruotsalainen
# --- Retrieving player info for: mark-hinz
# --- Retrieving player info for: emil-hedstrom
# --- Retrieving player info for: anthony-raiola
# --- Retrieving player info for: joni-forsander
# --- Retrieving player info for: tyler-levine
# --- Retrieving player info for: stepan-shtefan
# --- Retrieving player info for: matt-buchbinder
# --- Retrieving player info for: jorgen-jonsson
# --- Retrieving player info for: ben-nelson
# --- Retrieving player info for: andrei-altybarmakyan
# --- Retrieving player info for: alexei-kudreman
# --- Retrieving player info for: chris-waterstradt
# --- Retrieving player info for: davis-hart
# --- Retrieving player info for: vladimir-bolshanin
# --- Retrieving player info for: brenden-biedermann
# --- Retrieving player info for: tyrrel-wilson
# --- Retrieving player info for: joshua-lammon
# --- Retrieving player info for: semyon-ivanov
# --- Retrieving player info for: taylor-joseph
# --- Retrieving player info for: andrei-belevich
# --- Retrieving player info for: riley-weselowski
# --- Retrieving player info for: jason-fabian
# --- Retrieving player info for: ethan-mahoney
# --- Retrieving player info for: valtteri-suni
# --- Retrieving player info for: alexander-mirzabalayev
# --- Retrieving player info for: nikita-gerasimov
# --- Retrieving player info for: kieran-raymond
# --- Retrieving player info for: hunter-martin
# --- Retrieving player info for: johannes-latva
# --- Retrieving player info for: josh-zizek
# --- Retrieving player info for: alexei-alexeyev
# --- Retrieving player info for: david-nimmo
# --- Retrieving player info for: evan-fong
# --- Retrieving player info for: mike-mccann
# --- Retrieving player info for: fedor-gordeev
# --- Retrieving player info for: blake-murray
# --- Retrieving player info for: miroslav-duben
# --- Retrieving player info for: kyle-rossiter
# --- Retrieving player info for: igor-nesterov
# --- Retrieving player info for: alex-lucas
# --- Retrieving player info for: liam-leonard
# --- Retrieving player info for: jakub-ferenc
# --- Retrieving player info for: sam-dudley
# --- Retrieving player info for: jere-helenius
# --- Retrieving player info for: brandon-legare
# --- brandon-legare bad player data ---
# --- Retrieving player info for: steven-varga
# --- Retrieving player info for: shawn-fensel
# --- Retrieving player info for: emanuel-aucoin
# --- Retrieving player info for: jessy-morin
# --- Retrieving player info for: grayson-arnott
# --- Retrieving player info for: ty-lasker
# --- Retrieving player info for: niko-helavirta
# --- Retrieving player info for: tyler-cooke
# --- Retrieving player info for: ivan-shirokalov
# --- Retrieving player info for: branislav-fabry
# --- Retrieving player info for: hyun-ho-jang
# --- hyun-ho-jang bad player data ---
# --- Retrieving player info for: patrick-walsh
# --- Retrieving player info for: jacob-gaucher
# --- Retrieving player info for: mikhail-romanychev
# --- Retrieving player info for: matt-hounslow
# --- Retrieving player info for: david-homer
# --- Retrieving player info for: kyle-wilhelm
# --- Retrieving player info for: philippe-bergeron
# --- Retrieving player info for: anton-abrarov
# --- Retrieving player info for: matthew-danner
# --- Retrieving player info for: carter-wolski
# --- Retrieving player info for: damir-galin
# --- Retrieving player info for: zdenek-hrouda
# --- Retrieving player info for: dominik-crnogorac
# --- Retrieving player info for: tomas-schmidt
# --- Retrieving player info for: tomas-busek
# --- Retrieving player info for: ryley-wozniak
# --- Retrieving player info for: miika-makitalo
# --- Retrieving player info for: hubert-poulin
# --- Retrieving player info for: steve-miller
# --- Retrieving player info for: mike-stinton
# --- Retrieving player info for: zach-lorentz
# --- Retrieving player info for: ryan-helgason
# --- Retrieving player info for: damon-macdonald
# --- Retrieving player info for: anthony-bastianello
# --- Retrieving player info for: jack-millar
# --- Retrieving player info for: dmitri-klimashov
# --- Retrieving player info for: daniel-ridel
# --- Retrieving player info for: mikhail-paramonov
# --- Retrieving player info for: otto-leppanen
# --- Retrieving player info for: henrik-bjorklund
# --- Retrieving player info for: connor-hamilton
# --- Retrieving player info for: lukas-wahlberg
# --- Retrieving player info for: joona-riekkinen
# --- Retrieving player info for: nathan-everett
# --- Retrieving player info for: prokhor-korbit
# --- Retrieving player info for: yegor-kirillov
# --- Retrieving player info for: jan-danecek
# --- Retrieving player info for: toni-kiren
# --- Retrieving player info for: maxim-maltsev
# --- Retrieving player info for: tristan-fairbarn
# --- Retrieving player info for: joe-o-connor
# --- Retrieving player info for: jake-evans
# --- Retrieving player info for: eemil-laine
# --- Retrieving player info for: gabriel-paquin
# --- Retrieving player info for: alex-drover
# --- Retrieving player info for: david-ruzicka
# --- Retrieving player info for: michael-sardella
# --- Retrieving player info for: mark-o-blenis
# --- Retrieving player info for: tom-bilski
# --- Retrieving player info for: charles-farmer
# --- Retrieving player info for: cooper-johnson
# --- Retrieving player info for: guillaume-pelletier
# --- Retrieving player info for: patrick-christie
# --- Retrieving player info for: matthew-panetta
# --- Retrieving player info for: vladislav-voropayev
# --- Retrieving player info for: derek-bachynski
# --- Retrieving player info for: patrik-baarnhielm
# --- Retrieving player info for: pavel-zlobin
# --- Retrieving player info for: vaclav-rezek
# --- Retrieving player info for: brett-chandler
# --- Retrieving player info for: alexei-klochkov
# --- Retrieving player info for: tomas-knotek
# --- Retrieving player info for: anton-kokkonen
# --- Retrieving player info for: maximilien-daigle
# --- Retrieving player info for: daniil-peredry
# --- Retrieving player info for: zack-fisher
# --- Retrieving player info for: jyri-kankaanpaa
# --- Retrieving player info for: konnor-maccormick
# --- Retrieving player info for: paul-prescott
# --- Retrieving player info for: mikhail-kulakovsky
# --- Retrieving player info for: matthew-mccullough
# --- Retrieving player info for: alexei-leonov
# --- Retrieving player info for: chris-donovan
# --- Retrieving player info for: sergei-barbashev
# --- Retrieving player info for: jonathan-ouellet
# --- Retrieving player info for: curtis-perlin
# --- Retrieving player info for: alexander-lipin
# --- Retrieving player info for: niklas-niemi
# --- Retrieving player info for: adin-kennedy
# --- Retrieving player info for: lukas-kral
# --- Retrieving player info for: cole-beckstead
# --- Retrieving player info for: kyle-burton
# --- Retrieving player info for: bryan-hignett
# --- Retrieving player info for: julius-marva
# --- Retrieving player info for: mikhail-zhukov
# --- Retrieving player info for: alexander-karaulshchuk
# --- Retrieving player info for: vadim-mitryakov
# --- Retrieving player info for: matthew-plesa
# --- Retrieving player info for: joonas-valerius
# --- Retrieving player info for: jake-worrad
# --- Retrieving player info for: mathieu-parent
# --- Retrieving player info for: pierre-luc-huot
# --- Retrieving player info for: vladimir-kubus
# --- Retrieving player info for: ainur-vadigullin
# --- Retrieving player info for: tuomas-rahunen
# --- Retrieving player info for: robbie-lawrance
# --- Retrieving player info for: ilnaz-fakhrutdinov
# --- Retrieving player info for: robert-pelletier
# --- Retrieving player info for: pier-olivier-grandmaison
# --- Retrieving player info for: benoit-gervais
# --- Retrieving player info for: ivan-vasin
# --- Retrieving player info for: nikita-v.-novikov
# --- Retrieving player info for: kristian-kangas
# --- Retrieving player info for: matthew-cowley
# --- Retrieving player info for: jason-towsley
# --- Retrieving player info for: filip-prochazka
# --- Retrieving player info for: arto-koivisto
# --- Retrieving player info for: yevgeni-astankov
# --- Retrieving player info for: juuso-maenpaa
# --- Retrieving player info for: yegor-antonov
# --- Retrieving player info for: robert-bartek
# --- Retrieving player info for: yuri-seryakov
# --- Retrieving player info for: dmitri-sheshukov
# --- Retrieving player info for: jakub-schejbal
# --- Retrieving player info for: pavel-kopytin
# --- Retrieving player info for: finn-brown
# --- Retrieving player info for: david-tomasek
# --- Retrieving player info for: kevin-taylor
# --- Retrieving player info for: daniil-misyul
# --- Retrieving player info for: jorgen-sundqvist
# --- Retrieving player info for: tony-ignatius
# --- Retrieving player info for: nikita-khristov
# --- Retrieving player info for: juuso-fohr
# --- Retrieving player info for: fredrik-mannstrom
# --- Retrieving player info for: gabe-chabot
# --- Retrieving player info for: curtis-egert
# --- Retrieving player info for: tyler-hildebrandt
# --- Retrieving player info for: lukas-samuelsson
# --- Retrieving player info for: joe-tyran
# --- Retrieving player info for: derek-brown
# --- Retrieving player info for: lenny-thunderchild
# --- Retrieving player info for: vladimir-kondakov
# --- Retrieving player info for: jakub-viedemann
# --- Retrieving player info for: patrik-skacel
# --- Retrieving player info for: dinar-khairullov
# --- Retrieving player info for: igor-shvedov
# --- Retrieving player info for: david-lindquist
# --- Retrieving player info for: dylan-roobroeck
# --- Retrieving player info for: william-bengtsson-soderlund
# --- Retrieving player info for: matej-harkabus
# --- Retrieving player info for: matt-chartrain
# --- Retrieving player info for: ben-davy
# --- Retrieving player info for: kirill-slepets
# --- Retrieving player info for: tanner-williams
# --- Retrieving player info for: mikhail-radenko
# --- Retrieving player info for: olivier-bourret
# --- Retrieving player info for: derek-haylow
# --- Retrieving player info for: lucas-yovetich
# --- Retrieving player info for: matt-pepe
# --- Retrieving player info for: viktor-tokaji
# --- Retrieving player info for: konstantin-gulkin
# --- Retrieving player info for: nikita-moiseyev
# --- Retrieving player info for: david-pearce
# --- Retrieving player info for: benjamin-korhonen
# --- Retrieving player info for: konstantin-karpov
# --- Retrieving player info for: markus-talas
# --- Retrieving player info for: jeff-brown
# --- Retrieving player info for: roman-badanin
# --- Retrieving player info for: nicolas-lafontaine
# --- Retrieving player info for: branislav-kubka
# --- Retrieving player info for: drew-ellement
# --- Retrieving player info for: oldrich-horak
# --- Retrieving player info for: alex-beaton
# --- Retrieving player info for: alex-potter
# --- Retrieving player info for: bruno-birzitis
# --- Retrieving player info for: james-o-reilly
# --- Retrieving player info for: robi-kivilaakso
# --- Retrieving player info for: anton-pritykin
# --- Retrieving player info for: maxim-zyuzyakin
# --- Retrieving player info for: marko-sakic
# --- Retrieving player info for: anton-yefremov
# --- Retrieving player info for: cory-lauer
# --- Retrieving player info for: dan-caccavella
# --- Retrieving player info for: franco-colapaolo
# --- Retrieving player info for: ryan-maguire
# --- Retrieving player info for: jared-seminoff
# --- Retrieving player info for: jeremy-quenneville
# --- Retrieving player info for: casey-purpur
# --- Retrieving player info for: yegor-sofyin
# --- Retrieving player info for: patrick-marsh
# --- Retrieving player info for: robert-kantor
# --- Retrieving player info for: ivan-savin
# --- Retrieving player info for: kevin-o-connor
# --- Retrieving player info for: anton-sjoberg
# --- Retrieving player info for: mark-walchuk
# --- Retrieving player info for: vladislav-skorokhodov
# --- Retrieving player info for: vadim-kucherov
# --- Retrieving player info for: chris-meininger
# --- Retrieving player info for: jamie-milam
# --- Retrieving player info for: antti-holli
# --- Retrieving player info for: kai-magnussen
# --- Retrieving player info for: nikita-makeyev
# --- Retrieving player info for: jeff-collett
# --- Retrieving player info for: bobby-macdonald
# --- Retrieving player info for: david-hopfer
# --- Retrieving player info for: bogdan-denisevich
# --- Retrieving player info for: tommi-erkkila
# --- Retrieving player info for: yohann-mathieu
# --- Retrieving player info for: yaroslav-tulyakov
# --- Retrieving player info for: jordan-wyton
# --- Retrieving player info for: mikus-mintautiskis
# --- Retrieving player info for: adam-kalaj
# --- Retrieving player info for: niklas-karmhag
# --- Retrieving player info for: nathan-ward
# --- Retrieving player info for: nikita-malygin
# --- Retrieving player info for: jakub-kanik
# --- Retrieving player info for: alexandr-hegegy
# --- Retrieving player info for: patrik-bergstrom
# --- Retrieving player info for: grigori-babushkin
# --- Retrieving player info for: marek-dubec
# --- Retrieving player info for: quinton-fox
# --- Retrieving player info for: jacob-breckles
# --- Retrieving player info for: ove-molin
# --- Retrieving player info for: paul-d-agostino
# --- Retrieving player info for: michael-mcinerney
# --- Retrieving player info for: markus-lahtinen
# --- Retrieving player info for: justin-guitard
# --- Retrieving player info for: a.j.-d-orazio
# --- Retrieving player info for: miikka-riihimaki
# --- Retrieving player info for: rock-maurice
# --- Retrieving player info for: frederic-desrochers
# --- Retrieving player info for: kristian-skalin
# --- Retrieving player info for: alexander-bumagin
# --- Retrieving player info for: jack-graffi
# --- Retrieving player info for: maxim-semyonov
# --- Retrieving player info for: robbie-dowell
# --- Retrieving player info for: arturs-buss
# --- Retrieving player info for: jesse-rohtla
# --- Retrieving player info for: kenny-styles
# --- Retrieving player info for: alexandre-centis-jorge
# --- Retrieving player info for: luke-colavecchia
# --- Retrieving player info for: sergei-stupin
# --- Retrieving player info for: damir-rakhimullin
# --- Retrieving player info for: maxim-krivonozhkin
# --- Retrieving player info for: yevgeni-khvostov
# --- Retrieving player info for: matias-pulkkinen
# --- Retrieving player info for: jeremy-lapointe
# --- Retrieving player info for: darrin-trebes
# --- Retrieving player info for: jan-cikhart
# --- Retrieving player info for: adam-lukacovic
# --- Retrieving player info for: kyle-cecchetto
# --- Retrieving player info for: jakub-rumpel
# --- Retrieving player info for: brett-waters
# --- Retrieving player info for: jimmy-cusan
# --- Retrieving player info for: bjorn-eriksson
# --- Retrieving player info for: carl-olivier-dignard
# --- Retrieving player info for: kaleb-ergang
# --- Retrieving player info for: ryan-lehr
# --- Retrieving player info for: oskar-edstrom-petre
# --- Retrieving player info for: dominic-hachey
# --- Retrieving player info for: patrick-megannety
# --- Retrieving player info for: cam-mazur
# --- Retrieving player info for: percy-mielnik
# --- percy-mielnik bad player data ---
# --- Retrieving player info for: charles-olivier-ouimet
# --- Retrieving player info for: michael-falanga
# --- Retrieving player info for: kirill-sviyazov
# --- Retrieving player info for: lari-virkki
# --- Retrieving player info for: jeremiah-coon-come
# --- Retrieving player info for: yevgeni-gasnikov
# --- Retrieving player info for: kristian-grman
# --- Retrieving player info for: timy-luoto
# --- Retrieving player info for: jiaqi-zhang
# --- Retrieving player info for: casey-bickley
# --- Retrieving player info for: evan-accettura
# --- Retrieving player info for: stanislav-rangayev
# --- Retrieving player info for: tanner-sawka
# --- Retrieving player info for: mike-grobe
# --- Retrieving player info for: steven-savage
# --- Retrieving player info for: christian-magnusson
# --- Retrieving player info for: franco-sproviero
# --- Retrieving player info for: michael-best
# --- Retrieving player info for: stephen-johnston
# --- Retrieving player info for: jonathan-turk
# --- Retrieving player info for: petr-jurecka
# --- Retrieving player info for: josh-robertson
# --- Retrieving player info for: roman-mironikhin
# --- Retrieving player info for: cody-thompson
# --- Retrieving player info for: owen-kerr
# --- Retrieving player info for: joel-helle
# --- Retrieving player info for: daniel-selway
# --- Retrieving player info for: paul-rodrigues
# --- Retrieving player info for: connor-prudames
# --- Retrieving player info for: akseli-rouhiainen
# --- Retrieving player info for: joakim-huikkala
# --- Retrieving player info for: gregory-love
# --- Retrieving player info for: dallas-hines
# --- Retrieving player info for: devyn-mayea
# --- Retrieving player info for: danil-kozhedub
# --- Retrieving player info for: david-tuma
# --- Retrieving player info for: ludovic-beaupre
# --- Retrieving player info for: reece-harsch
# --- Retrieving player info for: aaron-archer
# --- Retrieving player info for: sampo-kettunen
# --- Retrieving player info for: vitali-nazarov
# --- Retrieving player info for: mike-martin
# --- Retrieving player info for: erik-ross
# --- Retrieving player info for: samuel-laitinen
# --- Retrieving player info for: jack-piper
# --- Retrieving player info for: taylor-lileikis
# --- Retrieving player info for: emile-bourque
# --- Retrieving player info for: jimi-ronkkonen
# --- Retrieving player info for: jake-klein
# --- Retrieving player info for: ilya-kudryashov
# --- Retrieving player info for: maxim-kolokolov
# --- Retrieving player info for: vaclav-lesak
# --- Retrieving player info for: vladislav-yartsev
# --- Retrieving player info for: jacob-harris
# --- Retrieving player info for: matt-nelson
# --- Retrieving player info for: tanner-labbe
# --- Retrieving player info for: matvei-misharin
# --- Retrieving player info for: vladislav-kulikov
# --- Retrieving player info for: zach-knapp-hermer
# --- Retrieving player info for: michael-mcgurk
# --- Retrieving player info for: carson-pearce
# --- Retrieving player info for: cayse-ton
# --- Retrieving player info for: yannick-provencher
# --- Retrieving player info for: taneli-kovaniemi
# --- Retrieving player info for: danil-pilyugin
# --- Retrieving player info for: ondrej-horinka
# --- Retrieving player info for: ossi-karhunen
# --- Retrieving player info for: matt-tugnutt
# --- Retrieving player info for: travis-mealey
# --- Retrieving player info for: tomas-psenicka
# --- Retrieving player info for: dmitri-zabolotnev
# --- Retrieving player info for: henry-roihu
# --- Retrieving player info for: ryan-anton
# --- Retrieving player info for: waltteri-virtanen
# --- Retrieving player info for: kyle-mcguigan
# --- kyle-mcguigan bad player data ---
# --- Retrieving player info for: liam-o-dette
# --- Retrieving player info for: daniel-holt
# --- Retrieving player info for: adam-bjorkman
# --- Retrieving player info for: nikita-ryzhkov
# --- Retrieving player info for: dylan-wallace
# --- Retrieving player info for: matt-maunu
# --- Retrieving player info for: cody-mcnaughton
# --- Retrieving player info for: joona-harjama
# --- Retrieving player info for: viljami-korhonen
# --- Retrieving player info for: miroslav-muzik
# --- Retrieving player info for: isaac-sooklal
# --- Retrieving player info for: dany-coulombe
# --- Retrieving player info for: ilnur-gilfanov
# --- Retrieving player info for: vitali-kafeyev
# --- Retrieving player info for: yevgeni-pastukh
# --- Retrieving player info for: jason-brancheau
# --- Retrieving player info for: jiri-parssinen
# --- Retrieving player info for: jake-ballagh
# --- Retrieving player info for: gage-olsen
# --- Retrieving player info for: trevor-bauer
# --- Retrieving player info for: brett-hahkala
# --- Retrieving player info for: tino-sandhu
# --- Retrieving player info for: jiri-beroun
# --- Retrieving player info for: travis-james
# --- Retrieving player info for: sam-leblanc
# --- Retrieving player info for: dan-beaudoin
# --- Retrieving player info for: jimi-nylund
# --- Retrieving player info for: vladislav-zhidkikh
# --- Retrieving player info for: blake-carrick
# --- Retrieving player info for: anton-malyshev
# --- Retrieving player info for: michal-sivek
# --- Retrieving player info for: roman-teslyuk
# --- Retrieving player info for: kabe-bleay
# --- Retrieving player info for: lukas-machac
# --- Retrieving player info for: daniyar-gabdullin
# --- Retrieving player info for: vladimir-malenkikh
# --- Retrieving player info for: jozef-balaz
# --- Retrieving player info for: grigori-aksyutov
# --- Retrieving player info for: yegor-arbuzov
# --- Retrieving player info for: paul-dahoy
# --- Retrieving player info for: james-scott
# --- Retrieving player info for: martin-jenacek
# --- Retrieving player info for: andrei-bashko
# --- Retrieving player info for: emil-galimov
# --- Retrieving player info for: sergei-zhukov
# --- Retrieving player info for: tomas-polak
# --- Retrieving player info for: adam-havener
# --- Retrieving player info for: yegor-krainov
# --- Retrieving player info for: joonas-karinkanta
# --- Retrieving player info for: ondrej-kopta
# --- Retrieving player info for: rasmus-orsa
# --- Retrieving player info for: adam-o-marra
# --- Retrieving player info for: nolan-regan
# --- Retrieving player info for: gleb-zaitsev
# --- Retrieving player info for: joshua-macpherson
# --- Retrieving player info for: vincent-keszi
# --- Retrieving player info for: maxim-volkov
# --- Retrieving player info for: daniel-tomassetti
# --- Retrieving player info for: martin-zatovic
# --- Retrieving player info for: sean-whitney
# --- Retrieving player info for: ville-osterman
# --- Retrieving player info for: derek-may
# --- Retrieving player info for: ondrej-podesva
# --- Retrieving player info for: joel-shoemaker
# --- Retrieving player info for: shawn-mackie
# --- Retrieving player info for: jordan-auld
# --- Retrieving player info for: daulet-kenbayev
# --- Retrieving player info for: olli-muittari
# --- Retrieving player info for: petr-heider
# --- Retrieving player info for: stefan-mann
# --- Retrieving player info for: curtis-fabbro
# --- Retrieving player info for: olli-ronkko
# --- Retrieving player info for: tucker-firth
# --- Retrieving player info for: roman-tatalin
# --- Retrieving player info for: zack-mungall
# --- Retrieving player info for: joe-kerker
# --- Retrieving player info for: kord-pankewicz
# --- Retrieving player info for: vitali-pinchuk
# --- Retrieving player info for: yegor-suchkov
# --- Retrieving player info for: matthew-schwehr
# --- Retrieving player info for: gerald-blackmore
# --- Retrieving player info for: nick-shkreli
# --- Retrieving player info for: bryce-woodward
# --- Retrieving player info for: bill-pinel
# --- Retrieving player info for: petr-hrach
# --- Retrieving player info for: john-christian
# --- Retrieving player info for: b.j.-bayers
# --- Retrieving player info for: nolen-coventry
# --- Retrieving player info for: adam-kuciak
# --- Retrieving player info for: nikolai-syomin
# --- Retrieving player info for: trevor-eckenswiller
# --- Retrieving player info for: darby-gula
# --- Retrieving player info for: artyom-oshchepkov
# --- Retrieving player info for: timofei-axyonenko
# --- Retrieving player info for: keegan-ferguson
# --- Retrieving player info for: billy-vida
# --- Retrieving player info for: dave-bertrand
# --- Retrieving player info for: andrew-mclennan
# --- Retrieving player info for: roope-turunen
# --- Retrieving player info for: derek-takeuchi
# --- Retrieving player info for: samuli-suhonen
# --- Retrieving player info for: valentin-shamayev
# --- Retrieving player info for: risto-saarinen
# --- Retrieving player info for: jordan-pelletier
# --- Retrieving player info for: olivier-luc-hache
# --- Retrieving player info for: tyler-prendergast
# --- Retrieving player info for: stanislav-kalashnikov
# --- Retrieving player info for: pavel-o.-vasilyev
# --- Retrieving player info for: johnathon-harrison
# --- Retrieving player info for: arttu-kaunisto
# --- Retrieving player info for: billy-seligman
# --- Retrieving player info for: alex-anderson
# --- Retrieving player info for: matt-smyth
# --- Retrieving player info for: mike-floyd
# --- Retrieving player info for: dan-grespan
# --- Retrieving player info for: vyacheslav-shmakov
# --- Retrieving player info for: jirko-puranen
# --- Retrieving player info for: antti-hujala
# --- Retrieving player info for: miika-roine
# --- Retrieving player info for: corey-houle
# --- Retrieving player info for: sergei-drovosekov
# --- Retrieving player info for: jaroslav-kreuzmann
# --- Retrieving player info for: tomi-korkko
# --- Retrieving player info for: joacim-hedblad
# --- Retrieving player info for: maxim-tsybin
# --- Retrieving player info for: mark-williams
# --- Retrieving player info for: roman-mikes
# --- Retrieving player info for: denis-tolpegin
# --- Retrieving player info for: marco-tuokko
# --- Retrieving player info for: blake-barbieri
# --- Retrieving player info for: casey-miller
# --- Retrieving player info for: aiden-wilson
# --- Retrieving player info for: fyodor-khrapak
# --- Retrieving player info for: brett-costello
# --- Retrieving player info for: sergei-zachupeyko
# --- Retrieving player info for: jesse-young
# --- Retrieving player info for: maxim-penyshkin
# --- Retrieving player info for: roman-meshkov
# --- Retrieving player info for: frantisek-ptacek
# --- Retrieving player info for: daniil-vertiy
# --- Retrieving player info for: jeff-hristovski
# --- Retrieving player info for: josh-booker
# --- Retrieving player info for: willy-paul
# --- Retrieving player info for: lance-herrington
# --- Retrieving player info for: tom-gronblom
# --- Retrieving player info for: brandon-kremer
# --- brandon-kremer bad player data ---
# --- Retrieving player info for: carl-philippe-ratts
# --- Retrieving player info for: casey-fox
# --- Retrieving player info for: cody-symonds
# --- Retrieving player info for: jon-asselstine
# --- Retrieving player info for: danny-plourde
# --- Retrieving player info for: konstantin-khrapsky
# --- Retrieving player info for: ross-scherma
# --- Retrieving player info for: dinmukhamed-dzhangarashev
# --- Retrieving player info for: jacob-spicer
# --- Retrieving player info for: riley-hennigar
# --- Retrieving player info for: brayden-goulet
# --- Retrieving player info for: olivier-donovan
# --- Retrieving player info for: markku-tahtinen
# --- Retrieving player info for: garrett-trainor
# --- Retrieving player info for: hayden-mccool
# ...
# --- Retrieving player info for: david-marek
# --- Retrieving player info for: vitali-belinsky
# --- Retrieving player info for: niels-erik-ravn
# --- Retrieving player info for: reese-jones
# --- Retrieving player info for: aidan-doak
# --- Retrieving player info for: ryan-wischow
# --- Retrieving player info for: fredrik-holmgren
# --- Retrieving player info for: tomas-sajdl
# --- Retrieving player info for: alexander-agopeyev
# --- Retrieving player info for: jake-maclennan
# --- Retrieving player info for: christoffer-rifalk
# --- Retrieving player info for: marcel-melichercik
# --- Retrieving player info for: cristobal-huet
# --- Retrieving player info for: yegor-stromin
# --- Retrieving player info for: joakim-strandberg
# --- Retrieving player info for: antoine-coulombe
# --- Retrieving player info for: simon-scherrer
# --- Retrieving player info for: mathieu-corbeil
# --- Retrieving player info for: alex-schilling
# --- Retrieving player info for: brayden-kelso
# --- Retrieving player info for: juuso-kannel
# --- Retrieving player info for: yuri-baturin
# --- Retrieving player info for: brayden-lachance
# --- Retrieving player info for: markus-olsson
# --- Retrieving player info for: anthony-felice
# --- Retrieving player info for: kris-moore
# --- Retrieving player info for: brett-epp
# --- Retrieving player info for: chris-collins
# --- Retrieving player info for: benjamin-conz
# --- Retrieving player info for: dusan-salficky
# --- Retrieving player info for: artyom-gvozdik
# --- Retrieving player info for: zackarias-skog
# --- Retrieving player info for: adam-svach
# --- Retrieving player info for: romi-huunonen
# --- Retrieving player info for: stefan-ridderwall
# --- Retrieving player info for: dean-shatzer
# --- Retrieving player info for: daniel-wenham
# --- Retrieving player info for: artyom-martynov
# --- Retrieving player info for: brendan-burke
# --- Retrieving player info for: james-povall
# --- Retrieving player info for: alex-wisco
# --- Retrieving player info for: andrew-shortridge
# --- Retrieving player info for: alex-kolkkinen
# --- Retrieving player info for: forbes-anderson
# --- Retrieving player info for: michael-caluori
# --- Retrieving player info for: maxim-yershov
# --- Retrieving player info for: chandler-long
# --- Retrieving player info for: daniil-galanov
# --- Retrieving player info for: jacob-tersigni
# --- Retrieving player info for: cole-bruns
# --- Retrieving player info for: jake-sibell
# --- Retrieving player info for: connor-wilkinson
# --- Retrieving player info for: brock-kautz
# --- Retrieving player info for: terrick-wilderman
# --- Retrieving player info for: victor-adamo
# --- Retrieving player info for: connor-hopkins
# --- Retrieving player info for: niclas-wolner-hanssen
# --- Retrieving player info for: wolfgang-zurrer
# --- Retrieving player info for: chris-neamonitis
# --- Retrieving player info for: braedon-fleming
# --- Retrieving player info for: neil-little
# --- Retrieving player info for: maxim-tretiak
# --- Retrieving player info for: chris-kingdon
# --- Retrieving player info for: colin-brennan
# --- Retrieving player info for: tyler-van-vliet
# --- Retrieving player info for: lauri-seppala
# --- Retrieving player info for: jesse-ehnisz
# --- Retrieving player info for: richie-laveau
# --- Retrieving player info for: olivier-pimpare-charbonneau
# --- Retrieving player info for: chris-festarini
# --- Retrieving player info for: nathan-marsters
# --- Retrieving player info for: severi-soukka
# --- Retrieving player info for: chris-jablonski
# --- Retrieving player info for: matthew-smidt
# --- Retrieving player info for: nathan-shield
# --- Retrieving player info for: viktor-andersson
# --- Retrieving player info for: clay-witt
# --- Retrieving player info for: antoine-samuel
# --- Retrieving player info for: rihards-cimermanis
# --- Retrieving player info for: patrik-pollanen
# --- Retrieving player info for: jack-walters
# --- jack-walters bad player data ---
# --- Retrieving player info for: anton-khudobin
# --- Retrieving player info for: richard-bachman
# --- Retrieving player info for: nikolas-simo
# --- Retrieving player info for: joe-keyser
# --- Retrieving player info for: joe-yetman
# --- Retrieving player info for: ryan-lenardon
# --- ryan-lenardon bad player data ---
# --- Retrieving player info for: jeremy-helvig
# --- Retrieving player info for: alexandre-michaud
# --- Retrieving player info for: garrett-bartus
# --- Retrieving player info for: josh-morton
# --- Retrieving player info for: nauris-enkuzens
# --- Retrieving player info for: emerson-verrier
# --- Retrieving player info for: frederic-cassivi
# --- Retrieving player info for: tomas-vosvrda
# --- Retrieving player info for: marc-andre-charron
# --- Retrieving player info for: steve-mnich
# --- Retrieving player info for: laurynas-lubys
# --- Retrieving player info for: tyrell-king
# --- Retrieving player info for: sean-cahill
# --- Retrieving player info for: daniel-dicamillo
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UndefinedColumn: column "catches" of relation "player_info" does not exist
# LINE 1: ...und, draft_pick, draft_team, nhl_draft, rankings, catches, d...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-71-4124f9e8de1c> in <module>
#      13 player_info = get_draft_eligibility(player_info)
#      14
# ---> 15 output_to_db(player_info, 'player_info')
#
# <ipython-input-39-0e332c919677> in output_to_db(df, name)
#      86     df = df.assign(load_date = datetime.date.today())
#      87     # write the values to the database
# ---> 88     df.to_sql(tables[name]['postgres'], engine, if_exists='append', index = False )
#      89
#      90 def output_to_csv(df, name):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     723             extras.execute_batch(cursor, statement, parameters)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#     727     @util.memoized_instancemethod
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "catches" of relation "player_info" does not exist
# LINE 1: ...und, draft_pick, draft_team, nhl_draft, rankings, catches, d...
#                                                              ^
#
# [SQL: INSERT INTO player_info (playerid, date_of_birth, place_of_birth, nation, height, weight, shoots, status, shortname, rights, under_contract, draft_year, draft_round, draft_pick, draft_team, nhl_draft, rankings, catches, draft_year_eligible, load_date) VALUES (%(playerid)s, %(date_of_birth)s, %(place_of_birth)s, %(nation)s, %(height)s, %(weight)s, %(shoots)s, %(status)s, %(shortname)s, %(rights)s, %(under_contract)s, %(draft_year)s, %(draft_round)s, %(draft_pick)s, %(draft_team)s, %(nhl_draft)s, %(rankings)s, %(catches)s, %(draft_year_eligible)s, %(load_date)s)]
# [parameters: ({'playerid': '32958', 'date_of_birth': datetime.datetime(1982, 1, 9, 0, 0), 'place_of_birth': 'Big Rapids, MI, USA', 'nation': 'USA', 'height': 173.0, 'weight': 77.0, 'shoots': 'L', 'status': 'Retired', 'shortname': 'josh-chase', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2000, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '49459', 'date_of_birth': datetime.datetime(1988, 11, 10, 0, 0), 'place_of_birth': 'Calgary, AB, CAN', 'nation': 'Canada', 'height': 185.0, 'weight': 93.0, 'shoots': 'L', 'status': 'Retired', 'shortname': 'jesse-hudkins', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2007, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '87894', 'date_of_birth': datetime.datetime(1994, 12, 29, 0, 0), 'place_of_birth': 'Kokkola, FIN', 'nation': 'Finland', 'height': 177.0, 'weight': 78.0, 'shoots': 'L', 'status': None, 'shortname': 'otto-mild', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2013, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '418678', 'date_of_birth': datetime.datetime(2000, 4, 13, 0, 0), 'place_of_birth': 'Brampton, ON, CAN', 'nation': 'Canada', 'height': 175.0, 'weight': 74.0, 'shoots': 'L', 'status': None, 'shortname': 'graham-watson', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2018, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '130769', 'date_of_birth': datetime.datetime(1986, 1, 9, 0, 0), 'place_of_birth': 'Fort McMurray, AB, CAN', 'nation': 'Canada', 'height': 180.0, 'weight': 82.0, 'shoots': 'R', 'status': None, 'shortname': 'logan-gorsalitz', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2004, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '18673', 'date_of_birth': datetime.datetime(1983, 6, 22, 0, 0), 'place_of_birth': 'Buffalo, MN, USA', 'nation': 'USA', 'height': 183.0, 'weight': 88.0, 'shoots': 'L', 'status': 'Retired', 'shortname': 'barnabas-birkeland', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2001, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '83475', 'date_of_birth': datetime.datetime(1995, 4, 8, 0, 0), 'place_of_birth': 'Lethbridge, AB, CAN', 'nation': 'Canada', 'height': 185.0, 'weight': 85.0, 'shoots': 'L', 'status': None, 'shortname': 'ryan-chynoweth', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2013, 'load_date': datetime.date(2020, 4, 16)}, {'playerid': '355487', 'date_of_birth': datetime.datetime(2000, 1, 18, 0, 0), 'place_of_birth': 'Toronto, ON, CAN', 'nation': 'Canada', 'height': 183.0, 'weight': 84.0, 'shoots': 'R', 'status': None, 'shortname': 'peter-stratis', 'rights': None, 'under_contract': None, 'draft_year': None, 'draft_round': None, 'draft_pick': None, 'draft_team': None, 'nhl_draft': None, 'rankings': None, 'catches': None, 'draft_year_eligible': 2018, 'load_date': datetime.date(2020, 4, 16)}  ... displaying 10 of 34259 total bound parameter sets ...  {'playerid': '25814', 'date_of_birth': datetime.datetime(1990, 3, 15, 0, 0), 'place_of_birth': 'Calgary,  ...
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
player_info.drop(columns=['catches'], inplace=True)

# %%
output_to_db(player_info, 'player_info')

# %% [markdown]
# ### debugging

# %%
teams, players, goalies = scrape_league_season_stats('NHL', '2005-2006')
# Out:
# --- Getting League Team Stats for NHL 2005-2006 ---
#
# --- Getting Team Player Stats for atlanta-thrashers 51 ---
# --- Getting Team Player Stats for boston-bruins 52 ---
# --- Getting Team Player Stats for buffalo-sabres 53 ---
# --- Getting Team Player Stats for calgary-flames 54 ---
# --- Getting Team Player Stats for carolina-hurricanes 55 ---
# --- Getting Team Player Stats for chicago-blackhawks 56 ---
# --- Getting Team Player Stats for colorado-avalanche 57 ---
# --- Getting Team Player Stats for columbus-blue-jackets 58 ---
# --- Getting Team Player Stats for dallas-stars 59 ---
# --- Getting Team Player Stats for detroit-red-wings 60 ---
# --- Getting Team Player Stats for edmonton-oilers 61 ---
# --- Getting Team Player Stats for florida-panthers 62 ---
# --- Getting Team Player Stats for los-angeles-kings 79 ---
# --- Getting Team Player Stats for mighty-ducks-of-anaheim 1580 ---
# --- Getting Team Player Stats for minnesota-wild 63 ---
# --- Getting Team Player Stats for montreal-canadiens 64 ---
# --- Getting Team Player Stats for nashville-predators 65 ---
# --- Getting Team Player Stats for new-jersey-devils 66 ---
# --- Getting Team Player Stats for new-york-islanders 67 ---
# --- Getting Team Player Stats for new-york-rangers 68 ---
# --- Getting Team Player Stats for ottawa-senators 69 ---
# --- Getting Team Player Stats for philadelphia-flyers 70 ---
# --- Getting Team Player Stats for phoenix-coyotes 72 ---
# --- Getting Team Player Stats for pittsburgh-penguins 71 ---
# --- Getting Team Player Stats for san-jose-sharks 73 ---
# --- Getting Team Player Stats for st.-louis-blues 74 ---
# --- Getting Team Player Stats for tampa-bay-lightning 75 ---
# --- Getting Team Player Stats for toronto-maple-leafs 76 ---
# --- Getting Team Player Stats for vancouver-canucks 77 ---
# --- Getting Team Player Stats for washington-capitals 78 ---

# %%
df = pd.read_csv('../../prospect_database/player_season_stats.csv')
# Out:
# /Users/connorjung/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df[(df.shortname == 'jesse-ylonen')]
# Out:
#        Unnamed: 0  playerid        player position  ... end_year season_age real_season_age next_season
# 11312       79491    299117  Jesse Ylönen     {RW}  ...     2017         18           18.25   2017-2018
# 57468       79492    299117  Jesse Ylönen     {RW}  ...     2019         20           20.24   2019-2020
# 71030       79493    299117  Jesse Ylönen     {RW}  ...     2020         21           21.25   2020-2021
#
# [3 rows x 41 columns]

# %%
teams
# Out:
#                              team teamid                                    shortname league  ...   gf   ga  gd   tp
# 0               BK Mlada Boleslav    699                            bk-mlada-boleslav  Czech  ...  156  164  -8   72
# 1              Bili Tygri Liberec    700                           bili-tygri-liberec  Czech  ...  128  131  -3   69
# 2         HC Energie Karlovy Vary    153                      hc-energie-karlovy-vary  Czech  ...  110  146 -36   62
# 3                  HC Kometa Brno   1190                               hc-kometa-brno  Czech  ...  153  135  18   95
# 4                     HC Litvinov    155                                  hc-litvinov  Czech  ...  167  120  47  105
# 5               HC Ocelari Trinec    161                            hc-ocelari-trinec  Czech  ...  183  117  66  107
# 6                      HC Olomouc   1240                                   hc-olomouc  Czech  ...  126  167 -41   54
# 7                        HC Plzen    637                                     hc-plzen  Czech  ...  144  133  11   75
# 8                 HC Slavia Praha    162                              hc-slavia-praha  Czech  ...  106  181 -75   44
# 9                 HC Sparta Praha    164                              hc-sparta-praha  Czech  ...  194  140  54   94
# 10             HC Vitkovice Steel    772                           hc-vitkovice-steel  Czech  ...  136  153 -17   75
# 11   HC ČSOB Pojišťovna Pardubice    159  hc-%C4%8Csob-poji%C5%A1%C5%A5ovna-pardubice  Czech  ...  143  156 -13   74
# 12              HK Hradec Kralove  15659                            hk-hradec-kralove  Czech  ...  136  131   5   85
# 13                       PSG Zlín    156                                     psg-zlin  Czech  ...  145  153  -8   81
#
# [14 rows x 15 columns]
